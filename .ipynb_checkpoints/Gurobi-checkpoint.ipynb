# %%
from optlang import Model, Variable, Constraint, Objective

# 定义变量
x1 = Variable('x1', lb=0)
x2 = Variable('x2', lb=0)

# 创建约束条件
c1 = Constraint(x1 + x2, ub=100)
c2 = Constraint(x1 + 2 * x2, ub=150)

# 定义目标函数
obj = Objective(25 * x1 + 20 * x2, direction='min')

# 创建模型
model = Model(name='Simple model')
model.objective = obj
model.add([c1, c2])

# 将求解器设置为Gurobi
model.solver = 'gurobi'

# 求解模型
status = model.optimize()

# 输出结果
print("status:", status)
print("objective value:", model.objective.value)
print("x1:", x1.primal)
print("x2:", x2.primal)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-17
# status: optimal
# objective value: 0.0
# x1: 0.0
# x2: 0.0

# %%
from cobra.io import read_sbml_model
from gurobipy import *

# %%
class Simulator():
    def __init__(self):
        self.cobra_model = None
        self.model_metabolites = None
        self.model_reactions = None
        self.model_genes = None
        self.Smatrix = None
        self.lower_boundary_constraints = None
        self.upper_boundary_constraints = None
        self.objective = None

    def read_model(self, filename):
        model = read_sbml_model(filename)
        self.cobra_model = model

        model_metabolites = [each_metabolite.id for each_metabolite in model.metabolites]
        model_reactions = []
        model_genes = [each_gene.id for each_gene in model.genes]

        Smatrix = {}

        lower_boundary_constraints = {}
        upper_boundary_constraints = {}

        objective_reaction = ''

        for each_reaction in model.reactions:
            if each_reaction.objective_coefficient == 1.0:
                objective_reaction = each_reaction.id

            reactant_list = each_reaction.reactants
            reactant_coff_list = list(each_reaction.get_coefficients(reactant_list))

            product_list = each_reaction.products
            product_coff_list = list(each_reaction.get_coefficients(product_list))

            for i in range(len(reactant_list)):
                Smatrix[(reactant_list[i].id, each_reaction.id)] = reactant_coff_list[i]

            for i in range(len(product_list)):
                Smatrix[(product_list[i].id, each_reaction.id)] = product_coff_list[i]

            model_reactions.append(each_reaction.id)

            lb = each_reaction.lower_bound
            ub = each_reaction.upper_bound
            if lb < -1000.0:
                lb = float('-inf')
            if ub > 1000.0:
                ub = float('inf')
            lower_boundary_constraints[each_reaction.id] = lb
            upper_boundary_constraints[each_reaction.id] = ub

        self.model_metabolites = model_metabolites
        self.model_reactions = model_reactions
        self.model_genes = model_genes
        self.Smatrix = Smatrix
        self.lower_boundary_constraints = lower_boundary_constraints
        self.upper_boundary_constraints = upper_boundary_constraints
        self.objective = objective_reaction

        return (model_metabolites, model_reactions, Smatrix,
                lower_boundary_constraints, upper_boundary_constraints, objective_reaction)

    def run_FBA(self, new_objective='', flux_constraints={}, inf_flag=False, internal_flux_minimization=False, mode='max'):
        lower_boundary_constraints = self.lower_boundary_constraints
        upper_boundary_constraints = self.upper_boundary_constraints

        if not inf_flag:
            for key in lower_boundary_constraints:
                if lower_boundary_constraints[key] == float("-inf"):
                    lower_boundary_constraints[key] = -1000.0

            for key in upper_boundary_constraints:
                if upper_boundary_constraints[key] == float("inf"):
                    upper_boundary_constraints[key] = 1000.0

        pairs, coffvalue = multidict(self.Smatrix)

        m = Model('FBA')
        m.setParam('OutputFlag', 0)
        m.reset()

        m.params.Threads = 1
        m.update()

        v = {}
        fplus = {}
        fminus = {}

        m.update()

        for each_reaction in self.model_reactions:
            if each_reaction in flux_constraints:
                v[each_reaction] = m.addVar(lb=flux_constraints[each_reaction][0],
                                            ub=flux_constraints[each_reaction][1], name=each_reaction)
            else:
                v[each_reaction] = m.addVar(lb=lower_boundary_constraints[each_reaction], ub=upper_boundary_constraints[each_reaction],
                                            name=each_reaction)
            fplus[each_reaction] = m.addVar(lb=0.0, ub=1000.0, name=each_reaction)
            fminus[each_reaction] = m.addVar(lb=0.0, ub=1000.0, name=each_reaction)
        m.update()

        for each_metabolite in self.model_metabolites:
            if len(pairs.select(each_metabolite, '*')) == 0:
                continue
            else:
                m.addConstr(quicksum(v[reaction] * coffvalue[metabolite, reaction] for metabolite, reaction in
                                 pairs.select(each_metabolite, '*')) == 0)
        m.update()

        if new_objective == '':
            objective = self.objective
        else:
            objective = new_objective

        if mode == 'max':
            m.setObjective(v[objective], GRB.MAXIMIZE)
        else:
            m.setObjective(v[objective], GRB.MINIMIZE)

        m.optimize()

        if m.status == 2:
            objective_value = m.ObjVal

            if internal_flux_minimization:
                m.addConstr(fplus[objective] - fminus[objective] == objective_value)
                # for each_metabolite in model_metabolites:???
                # fplus：正向通量 fminus：负向通量
                m.addConstr(quicksum(
                    (fplus[reaction] - fminus[reaction]) * coffvalue[metabolite, reaction] for metabolite, reaction in
                    pairs.select(each_metabolite, '*')) == 0)

                for each_reaction in self.model_reactions:
                    m.addConstr(fplus[each_reaction] - fminus[each_reaction] == v[each_reaction])

                m.update()
                m.setObjective(
                    quicksum((fplus[each_reaction] + fminus[each_reaction]) for each_reaction in self.model_reactions),
                    GRB.MINIMIZE)
                m.optimize()

                if m.status == 2:
                    objective_value = m.ObjVal
                    flux_distribution = {}
                    for reaction in self.model_reactions:
                        flux_distribution[reaction] = v[reaction].x
                    return m.status, objective_value, flux_distribution, pairs, coeffvalue

            else:
                flux_distribution = {}
                for reaction in self.model_reactions:
                    flux_distribution[reaction] = v[reaction].x
                    if abs(float(v[reaction].x)) <= 1e-6: # 1e-6?
                        flux_distribution[reaction] = 0.0
                return m.status, objective_value, flux_distribution
        return m.status, False, False

# %%
model_file = r"C:\Users\Victor\PycharmProjects\pythonProject\iBridge\input\iJO1366.xml"

simulator = Simulator()
model_metabolites, model_reactions, Smatrix, lower_boundary_constraints, upper_boundary_constraints, objective_reaction = simulator.read_model(model_file)

# %%
Smatrix
# Out:
# {('cm_e', 'EX_cm_e'): -1.0,
#  ('cmp_e', 'EX_cmp_e'): -1.0,
#  ('co2_e', 'EX_co2_e'): -1.0,
#  ('cobalt2_e', 'EX_cobalt2_e'): -1.0,
#  ('4crsol_c', 'DM_4crsol_c'): -1.0,
#  ('5drib_c', 'DM_5drib_c'): -1.0,
#  ('aacald_c', 'DM_aacald_c'): -1.0,
#  ('amob_c', 'DM_amob_c'): -1.0,
#  ('mththf_c', 'DM_mththf_c'): -1.0,
#  ('colipa_e', 'EX_colipa_e'): -1.0,
#  ('oxam_c', 'DM_oxam_c'): -1.0,
#  ('glc__D_e', 'EX_glc__D_e'): -1.0,
#  ('glcn_e', 'EX_glcn_e'): -1.0,
#  ('10fthf_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('2dmmql8_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('2fe2s_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -2.5e-05,
#  ('4fe4s_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000248,
#  ('5mthf_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('accoa_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000279,
#  ('adocbl_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('ala__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.499149,
#  ('amet_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('arg__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.28742,
#  ('asn__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.234232,
#  ('asp__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.234232,
#  ('atp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -54.119975,
#  ('bmocogdp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000116,
#  ('btn_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -2e-06,
#  ('ca2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.004952,
#  ('chor_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('cl_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.004952,
#  ('clpn160_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.002944,
#  ('clpn161_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.00229,
#  ('clpn181_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.00118,
#  ('coa_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000168,
#  ('cobalt2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -2.4e-05,
#  ('colipa_e', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.008151,
#  ('ctp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.129799,
#  ('cu2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000674,
#  ('cys__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.088988,
#  ('datp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.024805,
#  ('dctp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.025612,
#  ('dgtp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.025612,
#  ('dttp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.024805,
#  ('enter_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('fad_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('fe2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.006388,
#  ('fe3_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.007428,
#  ('gln__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.255712,
#  ('glu__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.255712,
#  ('gly_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.595297,
#  ('glycogen_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.154187,
#  ('gthrd_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('gtp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.209121,
#  ('h2o_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -48.752916,
#  ('hemeO_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('his__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.092056,
#  ('ile__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.282306,
#  ('k_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.18569,
#  ('leu__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.437778,
#  ('lipopb_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -3e-06,
#  ('lys__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.333448,
#  ('malcoa_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -3.1e-05,
#  ('met__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.149336,
#  ('mg2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.008253,
#  ('mlthf_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('mn2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000658,
#  ('mobd_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -7e-06,
#  ('mococdp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -7e-06,
#  ('mocogdp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -7e-06,
#  ('mql8_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('murein3p3p_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.001345,
#  ('murein3px4p_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000605,
#  ('murein4p4p_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.005381,
#  ('murein4px4p_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.005448,
#  ('murein4px4px4p_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000673,
#  ('nad_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.001787,
#  ('nadh_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -4.5e-05,
#  ('nadp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000112,
#  ('nadph_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000335,
#  ('nh4_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.012379,
#  ('ni2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000307,
#  ('pe160_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.012366,
#  ('pe160_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.031798,
#  ('pe161_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.009618,
#  ('pe161_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.024732,
#  ('pe181_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.004957,
#  ('pe181_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.012747,
#  ('pg160_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.005707,
#  ('pg160_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.004892,
#  ('pg161_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.004439,
#  ('pg161_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.003805,
#  ('pg181_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.002288,
#  ('pg181_p', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.001961,
#  ('phe__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.180021,
#  ('pheme_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('pro__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.214798,
#  ('ptrc_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.03327,
#  ('pydx5p_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('q8h2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('ribflv_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('ser__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.209684,
#  ('sheme_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('so4_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.004126,
#  ('spmd_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.006744,
#  ('succoa_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -9.8e-05,
#  ('thf_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('thmpp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000223,
#  ('thr__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.246506,
#  ('trp__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.055234,
#  ('tyr__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.133993,
#  ('udcpdp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -5.5e-05,
#  ('utp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.140101,
#  ('val__L_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.411184,
#  ('zn2_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): -0.000324,
#  ('adp_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): 53.95,
#  ('h_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): 53.95,
#  ('pi_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): 53.945874,
#  ('ppi_c', 'BIOMASS_Ec_iJO1366_WT_53p95M'): 0.749831,
#  ('glcr_e', 'EX_glcr_e'): -1.0,
#  ('colipap_e', 'EX_colipap_e'): -1.0,
#  ('glcur_e', 'EX_glcur_e'): -1.0,
#  ('glcur1p_e', 'EX_glcur1p_e'): -1.0,
#  ('10fthf_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('2fe2s_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -2.6e-05,
#  ('2ohph_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('4fe4s_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.00026,
#  ('ala__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.513689,
#  ('amet_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('arg__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.295792,
#  ('asn__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.241055,
#  ('asp__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.241055,
#  ('atp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -54.124831,
#  ('bmocogdp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000122,
#  ('btn_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -2e-06,
#  ('ca2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.005205,
#  ('cl_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.005205,
#  ('coa_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000576,
#  ('cobalt2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -2.5e-05,
#  ('ctp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.133508,
#  ('cu2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000709,
#  ('cys__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.09158,
#  ('datp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.026166,
#  ('dctp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.027017,
#  ('dgtp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.027017,
#  ('dttp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.026166,
#  ('fad_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('fe2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.006715,
#  ('fe3_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.007808,
#  ('gln__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.26316,
#  ('glu__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.26316,
#  ('gly_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.612638,
#  ('gtp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.215096,
#  ('h2o_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -48.601527,
#  ('his__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.094738,
#  ('ile__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.290529,
#  ('k_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.195193,
#  ('kdo2lipid4_e', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.019456,
#  ('leu__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.450531,
#  ('lys__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.343161,
#  ('met__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.153686,
#  ('mg2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.008675,
#  ('mlthf_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('mn2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000691,
#  ('mobd_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -7e-06,
#  ('murein5px4p_p', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.013894,
#  ('nad_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.001831,
#  ('nadp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000447,
#  ('nh4_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.013013,
#  ('ni2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000323,
#  ('pe160_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.017868,
#  ('pe160_p', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.045946,
#  ('pe161_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.054154,
#  ('pe161_p', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.02106,
#  ('phe__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.185265,
#  ('pheme_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('pro__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.221055,
#  ('pydx5p_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('ribflv_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('ser__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.215792,
#  ('sheme_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('so4_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.004338,
#  ('thf_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('thmpp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000223,
#  ('thr__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.253687,
#  ('trp__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.056843,
#  ('tyr__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.137896,
#  ('udcpdp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -5.5e-05,
#  ('utp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.144104,
#  ('val__L_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.423162,
#  ('zn2_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): -0.000341,
#  ('adp_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): 53.95,
#  ('h_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): 53.95,
#  ('pi_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): 53.945662,
#  ('ppi_c', 'BIOMASS_Ec_iJO1366_core_53p95M'): 0.773903,
#  ('12ppd__R_e', 'EX_12ppd__R_e'): -1.0,
#  ('gln__L_e', 'EX_gln__L_e'): -1.0,
#  ('cpgn_e', 'EX_cpgn_e'): -1.0,
#  ('glu__L_e', 'EX_glu__L_e'): -1.0,
#  ('gly_e', 'EX_gly_e'): -1.0,
#  ('glyald_e', 'EX_glyald_e'): -1.0,
#  ('glyb_e', 'EX_glyb_e'): -1.0,
#  ('glyc_e', 'EX_glyc_e'): -1.0,
#  ('12ppd__S_e', 'EX_12ppd__S_e'): -1.0,
#  ('14glucan_e', 'EX_14glucan_e'): -1.0,
#  ('cpgn_un_e', 'EX_cpgn_un_e'): -1.0,
#  ('15dap_e', 'EX_15dap_e'): -1.0,
#  ('glyc__R_e', 'EX_glyc__R_e'): -1.0,
#  ('glyc2p_e', 'EX_glyc2p_e'): -1.0,
#  ('23camp_e', 'EX_23camp_e'): -1.0,
#  ('23ccmp_e', 'EX_23ccmp_e'): -1.0,
#  ('23cgmp_e', 'EX_23cgmp_e'): -1.0,
#  ('23cump_e', 'EX_23cump_e'): -1.0,
#  ('23dappa_e', 'EX_23dappa_e'): -1.0,
#  ('26dap__M_e', 'EX_26dap__M_e'): -1.0,
#  ('glyc3p_e', 'EX_glyc3p_e'): -1.0,
#  ('glyclt_e', 'EX_glyclt_e'): -1.0,
#  ('gmp_e', 'EX_gmp_e'): -1.0,
#  ('gsn_e', 'EX_gsn_e'): -1.0,
#  ('gthox_e', 'EX_gthox_e'): -1.0,
#  ('gthrd_e', 'EX_gthrd_e'): -1.0,
#  ('gtp_e', 'EX_gtp_e'): -1.0,
#  ('gua_e', 'EX_gua_e'): -1.0,
#  ('h_e', 'EX_h_e'): -1.0,
#  ('h2_e', 'EX_h2_e'): -1.0,
#  ('h2o_e', 'EX_h2o_e'): -1.0,
#  ('h2o2_e', 'EX_h2o2_e'): -1.0,
#  ('h2s_e', 'EX_h2s_e'): -1.0,
#  ('hacolipa_e', 'EX_hacolipa_e'): -1.0,
#  ('halipa_e', 'EX_halipa_e'): -1.0,
#  ('hdca_e', 'EX_hdca_e'): -1.0,
#  ('hdcea_e', 'EX_hdcea_e'): -1.0,
#  ('hg2_e', 'EX_hg2_e'): -1.0,
#  ('his__L_e', 'EX_his__L_e'): -1.0,
#  ('2ddglcn_e', 'EX_2ddglcn_e'): -1.0,
#  ('34dhpac_e', 'EX_34dhpac_e'): -1.0,
#  ('3amp_e', 'EX_3amp_e'): -1.0,
#  ('3cmp_e', 'EX_3cmp_e'): -1.0,
#  ('3gmp_e', 'EX_3gmp_e'): -1.0,
#  ('3hcinnm_e', 'EX_3hcinnm_e'): -1.0,
#  ('3hpp_e', 'EX_3hpp_e'): -1.0,
#  ('3hpppn_e', 'EX_3hpppn_e'): -1.0,
#  ('hom__L_e', 'EX_hom__L_e'): -1.0,
#  ('hxa_e', 'EX_hxa_e'): -1.0,
#  ('hxan_e', 'EX_hxan_e'): -1.0,
#  ('idon__L_e', 'EX_idon__L_e'): -1.0,
#  ('3ump_e', 'EX_3ump_e'): -1.0,
#  ('4abut_e', 'EX_4abut_e'): -1.0,
#  ('4hoxpacd_e', 'EX_4hoxpacd_e'): -1.0,
#  ('5dglcn_e', 'EX_5dglcn_e'): -1.0,
#  ('5mtr_e', 'EX_5mtr_e'): -1.0,
#  ('LalaDglu_e', 'EX_LalaDglu_e'): -1.0,
#  ('ile__L_e', 'EX_ile__L_e'): -1.0,
#  ('imp_e', 'EX_imp_e'): -1.0,
#  ('indole_e', 'EX_indole_e'): -1.0,
#  ('inost_e', 'EX_inost_e'): -1.0,
#  ('ins_e', 'EX_ins_e'): -1.0,
#  ('isetac_e', 'EX_isetac_e'): -1.0,
#  ('k_e', 'EX_k_e'): -1.0,
#  ('LalaDgluMdap_e', 'EX_LalaDgluMdap_e'): -1.0,
#  ('LalaDgluMdapDala_e', 'EX_LalaDgluMdapDala_e'): -1.0,
#  ('LalaLglu_e', 'EX_LalaLglu_e'): -1.0,
#  ('kdo2lipid4_e', 'EX_kdo2lipid4_e'): -1.0,
#  ('ac_e', 'EX_ac_e'): -1.0,
#  ('crn_e', 'EX_crn_e'): -1.0,
#  ('acac_e', 'EX_acac_e'): -1.0,
#  ('acald_e', 'EX_acald_e'): -1.0,
#  ('lac__D_e', 'EX_lac__D_e'): -1.0,
#  ('lac__L_e', 'EX_lac__L_e'): -1.0,
#  ('crn__D_e', 'EX_crn__D_e'): -1.0,
#  ('lcts_e', 'EX_lcts_e'): -1.0,
#  ('acgal_e', 'EX_acgal_e'): -1.0,
#  ('acgal1p_e', 'EX_acgal1p_e'): -1.0,
#  ('acgam_e', 'EX_acgam_e'): -1.0,
#  ('leu__L_e', 'EX_leu__L_e'): -1.0,
#  ('csn_e', 'EX_csn_e'): -1.0,
#  ('acgam1p_e', 'EX_acgam1p_e'): -1.0,
#  ('acmana_e', 'EX_acmana_e'): -1.0,
#  ('acmum_e', 'EX_acmum_e'): -1.0,
#  ('lipa_e', 'EX_lipa_e'): -1.0,
#  ('cu_e', 'EX_cu_e'): -1.0,
#  ('lipa_cold_e', 'EX_lipa_cold_e'): -1.0,
#  ('acnam_e', 'EX_acnam_e'): -1.0,
#  ('acolipa_e', 'EX_acolipa_e'): -1.0,
#  ('cu2_e', 'EX_cu2_e'): -1.0,
#  ('acser_e', 'EX_acser_e'): -1.0,
#  ('ade_e', 'EX_ade_e'): -1.0,
#  ('adn_e', 'EX_adn_e'): -1.0,
#  ('adocbl_e', 'EX_adocbl_e'): -1.0,
#  ('ag_e', 'EX_ag_e'): -1.0,
#  ('lipoate_e', 'EX_lipoate_e'): -1.0,
#  ('lys__L_e', 'EX_lys__L_e'): -1.0,
#  ('lyx__L_e', 'EX_lyx__L_e'): -1.0,
#  ('mal__D_e', 'EX_mal__D_e'): -1.0,
#  ('agm_e', 'EX_agm_e'): -1.0,
#  ('akg_e', 'EX_akg_e'): -1.0,
#  ('cyan_e', 'EX_cyan_e'): -1.0,
#  ('ala_B_e', 'EX_ala_B_e'): -1.0,
#  ('ala__D_e', 'EX_ala__D_e'): -1.0,
#  ('ala__L_e', 'EX_ala__L_e'): -1.0,
#  ('alaala_e', 'EX_alaala_e'): -1.0,
#  ('all__D_e', 'EX_all__D_e'): -1.0,
#  ('alltn_e', 'EX_alltn_e'): -1.0,
#  ('amp_e', 'EX_amp_e'): -1.0,
#  ('anhgm_e', 'EX_anhgm_e'): -1.0,
#  ('arab__L_e', 'EX_arab__L_e'): -1.0,
#  ('mal__L_e', 'EX_mal__L_e'): -1.0,
#  ('malt_e', 'EX_malt_e'): -1.0,
#  ('malthx_e', 'EX_malthx_e'): -1.0,
#  ('maltpt_e', 'EX_maltpt_e'): -1.0,
#  ('malttr_e', 'EX_malttr_e'): -1.0,
#  ('maltttr_e', 'EX_maltttr_e'): -1.0,
#  ('man_e', 'EX_man_e'): -1.0,
#  ('cynt_e', 'EX_cynt_e'): -1.0,
#  ('man6p_e', 'EX_man6p_e'): -1.0,
#  ('manglyc_e', 'EX_manglyc_e'): -1.0,
#  ('melib_e', 'EX_melib_e'): -1.0,
#  ('cys__D_e', 'EX_cys__D_e'): -1.0,
#  ('meoh_e', 'EX_meoh_e'): -1.0,
#  ('met__D_e', 'EX_met__D_e'): -1.0,
#  ('arbt_e', 'EX_arbt_e'): -1.0,
#  ('arbtn_e', 'EX_arbtn_e'): -1.0,
#  ('arbtn_fe3_e', 'EX_arbtn_fe3_e'): -1.0,
#  ('met__L_e', 'EX_met__L_e'): -1.0,
#  ('cys__L_e', 'EX_cys__L_e'): -1.0,
#  ('metsox_R__L_e', 'EX_metsox_R__L_e'): -1.0,
#  ('metsox_S__L_e', 'EX_metsox_S__L_e'): -1.0,
#  ('mg2_e', 'EX_mg2_e'): -1.0,
#  ('mincyc_e', 'EX_mincyc_e'): -1.0,
#  ('minohp_e', 'EX_minohp_e'): -1.0,
#  ('mmet_e', 'EX_mmet_e'): -1.0,
#  ('arg__L_e', 'EX_arg__L_e'): -1.0,
#  ('ascb__L_e', 'EX_ascb__L_e'): -1.0,
#  ('asn__L_e', 'EX_asn__L_e'): -1.0,
#  ('aso3_e', 'EX_aso3_e'): -1.0,
#  ('asp__L_e', 'EX_asp__L_e'): -1.0,
#  ('btn_e', 'EX_btn_e'): -1.0,
#  ('but_e', 'EX_but_e'): -1.0,
#  ('mn2_e', 'EX_mn2_e'): -1.0,
#  ('mnl_e', 'EX_mnl_e'): -1.0,
#  ('mobd_e', 'EX_mobd_e'): -1.0,
#  ('mso3_e', 'EX_mso3_e'): -1.0,
#  ('n2o_e', 'EX_n2o_e'): -1.0,
#  ('na1_e', 'EX_na1_e'): -1.0,
#  ('nac_e', 'EX_nac_e'): -1.0,
#  ('nh4_e', 'EX_nh4_e'): -1.0,
#  ('butso3_e', 'EX_butso3_e'): -1.0,
#  ('ca2_e', 'EX_ca2_e'): -1.0,
#  ('cbi_e', 'EX_cbi_e'): -1.0,
#  ('cytd_e', 'EX_cytd_e'): -1.0,
#  ('cbl1_e', 'EX_cbl1_e'): -1.0,
#  ('cd2_e', 'EX_cd2_e'): -1.0,
#  ('cgly_e', 'EX_cgly_e'): -1.0,
#  ('ni2_e', 'EX_ni2_e'): -1.0,
#  ('nmn_e', 'EX_nmn_e'): -1.0,
#  ('no_e', 'EX_no_e'): -1.0,
#  ('no2_e', 'EX_no2_e'): -1.0,
#  ('no3_e', 'EX_no3_e'): -1.0,
#  ('novbcn_e', 'EX_novbcn_e'): -1.0,
#  ('o16a4colipa_e', 'EX_o16a4colipa_e'): -1.0,
#  ('o2_e', 'EX_o2_e'): -1.0,
#  ('o2s_e', 'EX_o2s_e'): -1.0,
#  ('ocdca_e', 'EX_ocdca_e'): -1.0,
#  ('ocdcea_e', 'EX_ocdcea_e'): -1.0,
#  ('octa_e', 'EX_octa_e'): -1.0,
#  ('orn_e', 'EX_orn_e'): -1.0,
#  ('orot_e', 'EX_orot_e'): -1.0,
#  ('pacald_e', 'EX_pacald_e'): -1.0,
#  ('peamn_e', 'EX_peamn_e'): -1.0,
#  ('phe__L_e', 'EX_phe__L_e'): -1.0,
#  ('pheme_e', 'EX_pheme_e'): -1.0,
#  ('chol_e', 'EX_chol_e'): -1.0,
#  ('chtbs_e', 'EX_chtbs_e'): -1.0,
#  ('cit_e', 'EX_cit_e'): -1.0,
#  ('cl_e', 'EX_cl_e'): -1.0,
#  ('pi_e', 'EX_pi_e'): -1.0,
#  ('dad_2_e', 'EX_dad_2_e'): -1.0,
#  ('pnto__R_e', 'EX_pnto__R_e'): -1.0,
#  ('ppa_e', 'EX_ppa_e'): -1.0,
#  ('damp_e', 'EX_damp_e'): -1.0,
#  ('ppal_e', 'EX_ppal_e'): -1.0,
#  ('dca_e', 'EX_dca_e'): -1.0,
#  ('pppn_e', 'EX_pppn_e'): -1.0,
#  ('ppt_e', 'EX_ppt_e'): -1.0,
#  ('dcmp_e', 'EX_dcmp_e'): -1.0,
#  ('pro__L_e', 'EX_pro__L_e'): -1.0,
#  ('dcyt_e', 'EX_dcyt_e'): -1.0,
#  ('progly_e', 'EX_progly_e'): -1.0,
#  ('psclys_e', 'EX_psclys_e'): -1.0,
#  ('ddca_e', 'EX_ddca_e'): -1.0,
#  ('pser__L_e', 'EX_pser__L_e'): -1.0,
#  ('ptrc_e', 'EX_ptrc_e'): -1.0,
#  ('dgmp_e', 'EX_dgmp_e'): -1.0,
#  ('dgsn_e', 'EX_dgsn_e'): -1.0,
#  ('val__L_e', 'EX_val__L_e'): -1.0,
#  ('xan_e', 'EX_xan_e'): -1.0,
#  ('dha_e', 'EX_dha_e'): -1.0,
#  ('xmp_e', 'EX_xmp_e'): -1.0,
#  ('dimp_e', 'EX_dimp_e'): -1.0,
#  ('din_e', 'EX_din_e'): -1.0,
#  ('xtsn_e', 'EX_xtsn_e'): -1.0,
#  ('pydam_e', 'EX_pydam_e'): -1.0,
#  ('xyl__D_e', 'EX_xyl__D_e'): -1.0,
#  ('xylu__L_e', 'EX_xylu__L_e'): -1.0,
#  ('zn2_e', 'EX_zn2_e'): -1.0,
#  ('12dgr120_p', '12DGR120tipp'): -1.0,
#  ('12dgr120_c', '12DGR120tipp'): 1.0,
#  ('12dgr140_p', '12DGR140tipp'): -1.0,
#  ('12dgr140_c', '12DGR140tipp'): 1.0,
#  ('12dgr141_p', '12DGR141tipp'): -1.0,
#  ('12dgr141_c', '12DGR141tipp'): 1.0,
#  ('12dgr160_p', '12DGR160tipp'): -1.0,
#  ('12dgr160_c', '12DGR160tipp'): 1.0,
#  ('12dgr161_p', '12DGR161tipp'): -1.0,
#  ('12dgr161_c', '12DGR161tipp'): 1.0,
#  ('12dgr180_p', '12DGR180tipp'): -1.0,
#  ('12dgr180_c', '12DGR180tipp'): 1.0,
#  ('pydx_e', 'EX_pydx_e'): -1.0,
#  ('pydxn_e', 'EX_pydxn_e'): -1.0,
#  ('pyr_e', 'EX_pyr_e'): -1.0,
#  ('quin_e', 'EX_quin_e'): -1.0,
#  ('r5p_e', 'EX_r5p_e'): -1.0,
#  ('rfamp_e', 'EX_rfamp_e'): -1.0,
#  ('rib__D_e', 'EX_rib__D_e'): -1.0,
#  ('rmn_e', 'EX_rmn_e'): -1.0,
#  ('sbt__D_e', 'EX_sbt__D_e'): -1.0,
#  ('sel_e', 'EX_sel_e'): -1.0,
#  ('ser__D_e', 'EX_ser__D_e'): -1.0,
#  ('ser__L_e', 'EX_ser__L_e'): -1.0,
#  ('skm_e', 'EX_skm_e'): -1.0,
#  ('12dgr181_p', '12DGR181tipp'): -1.0,
#  ('12dgr181_c', '12DGR181tipp'): 1.0,
#  ('12ppd__R_e', '12PPDRtex'): -1.0,
#  ('12ppd__R_p', '12PPDRtex'): 1.0,
#  ('12ppd__R_p', '12PPDRtpp'): -1.0,
#  ('12ppd__R_c', '12PPDRtpp'): 1.0,
#  ('dms_e', 'EX_dms_e'): -1.0,
#  ('12ppd__S_e', '12PPDStex'): -1.0,
#  ('12ppd__S_p', '12PPDStex'): 1.0,
#  ('12ppd__S_p', '12PPDStpp'): -1.0,
#  ('12ppd__S_c', '12PPDStpp'): 1.0,
#  ('14glucan_p', '14GLUCANabcpp'): -1.0,
#  ('atp_c', '14GLUCANabcpp'): -1.0,
#  ('h2o_c', '14GLUCANabcpp'): -1.0,
#  ('14glucan_c', '14GLUCANabcpp'): 1.0,
#  ('adp_c', '14GLUCANabcpp'): 1.0,
#  ('h_c', '14GLUCANabcpp'): 1.0,
#  ('pi_c', '14GLUCANabcpp'): 1.0,
#  ('slnt_e', 'EX_slnt_e'): -1.0,
#  ('so2_e', 'EX_so2_e'): -1.0,
#  ('so3_e', 'EX_so3_e'): -1.0,
#  ('dmso_e', 'EX_dmso_e'): -1.0,
#  ('so4_e', 'EX_so4_e'): -1.0,
#  ('spmd_e', 'EX_spmd_e'): -1.0,
#  ('succ_e', 'EX_succ_e'): -1.0,
#  ('14glucan_e', '14GLUCANtexi'): -1.0,
#  ('14glucan_p', '14GLUCANtexi'): 1.0,
#  ('23camp_e', '23CAMPtex'): -1.0,
#  ('23camp_p', '23CAMPtex'): 1.0,
#  ('23ccmp_e', '23CCMPtex'): -1.0,
#  ('23ccmp_p', '23CCMPtex'): 1.0,
#  ('sucr_e', 'EX_sucr_e'): -1.0,
#  ('sulfac_e', 'EX_sulfac_e'): -1.0,
#  ('23cgmp_e', '23CGMPtex'): -1.0,
#  ('23cgmp_p', '23CGMPtex'): 1.0,
#  ('tartr__D_e', 'EX_tartr__D_e'): -1.0,
#  ('23cump_e', '23CUMPtex'): -1.0,
#  ('23cump_p', '23CUMPtex'): 1.0,
#  ('dopa_e', 'EX_dopa_e'): -1.0,
#  ('23dappa_p', '23DAPPAt2pp'): -1.0,
#  ('h_p', '23DAPPAt2pp'): -1.0,
#  ('23dappa_c', '23DAPPAt2pp'): 1.0,
#  ('h_c', '23DAPPAt2pp'): 1.0,
#  ('23dappa_e', '23DAPPAtex'): -1.0,
#  ('23dappa_p', '23DAPPAtex'): 1.0,
#  ('23cump_p', '23PDE2pp'): -1.0,
#  ('h2o_p', '23PDE2pp'): -1.0,
#  ('3ump_p', '23PDE2pp'): 1.0,
#  ('h_p', '23PDE2pp'): 1.0,
#  ('23ccmp_p', '23PDE4pp'): -1.0,
#  ('h2o_p', '23PDE4pp'): -1.0,
#  ('3cmp_p', '23PDE4pp'): 1.0,
#  ('h_p', '23PDE4pp'): 1.0,
#  ('tartr__L_e', 'EX_tartr__L_e'): -1.0,
#  ('taur_e', 'EX_taur_e'): -1.0,
#  ('tcynt_e', 'EX_tcynt_e'): -1.0,
#  ('23camp_p', '23PDE7pp'): -1.0,
#  ('h2o_p', '23PDE7pp'): -1.0,
#  ('3amp_p', '23PDE7pp'): 1.0,
#  ('h_p', '23PDE7pp'): 1.0,
#  ('23cgmp_p', '23PDE9pp'): -1.0,
#  ('h2o_p', '23PDE9pp'): -1.0,
#  ('3gmp_p', '23PDE9pp'): 1.0,
#  ('h_p', '23PDE9pp'): 1.0,
#  ('doxrbcn_e', 'EX_doxrbcn_e'): -1.0,
#  ('26dap__M_e', '26DAHtex'): -1.0,
#  ('26dap__M_p', '26DAHtex'): 1.0,
#  ('2ddecg3p_p', '2AGPA120tipp'): -1.0,
#  ('2ddecg3p_c', '2AGPA120tipp'): 1.0,
#  ('thm_e', 'EX_thm_e'): -1.0,
#  ('thr__L_e', 'EX_thr__L_e'): -1.0,
#  ('dtmp_e', 'EX_dtmp_e'): -1.0,
#  ('thrp_e', 'EX_thrp_e'): -1.0,
#  ('2tdecg3p_p', '2AGPA140tipp'): -1.0,
#  ('2tdecg3p_c', '2AGPA140tipp'): 1.0,
#  ('2tdec7eg3p_p', '2AGPA141tipp'): -1.0,
#  ('2tdec7eg3p_c', '2AGPA141tipp'): 1.0,
#  ('thym_e', 'EX_thym_e'): -1.0,
#  ('dump_e', 'EX_dump_e'): -1.0,
#  ('thymd_e', 'EX_thymd_e'): -1.0,
#  ('2hdecg3p_p', '2AGPA160tipp'): -1.0,
#  ('2hdecg3p_c', '2AGPA160tipp'): 1.0,
#  ('2hdec9eg3p_p', '2AGPA161tipp'): -1.0,
#  ('2hdec9eg3p_c', '2AGPA161tipp'): 1.0,
#  ('tma_e', 'EX_tma_e'): -1.0,
#  ('duri_e', 'EX_duri_e'): -1.0,
#  ('tmao_e', 'EX_tmao_e'): -1.0,
#  ('tre_e', 'EX_tre_e'): -1.0,
#  ('trp__L_e', 'EX_trp__L_e'): -1.0,
#  ('2odecg3p_p', '2AGPA180tipp'): -1.0,
#  ('2odecg3p_c', '2AGPA180tipp'): 1.0,
#  ('2odec11eg3p_p', '2AGPA181tipp'): -1.0,
#  ('2odec11eg3p_c', '2AGPA181tipp'): 1.0,
#  ('2agpe120_p', '2AGPE120tipp'): -1.0,
#  ('2agpe120_c', '2AGPE120tipp'): 1.0,
#  ('2agpe140_p', '2AGPE140tipp'): -1.0,
#  ('2agpe140_c', '2AGPE140tipp'): 1.0,
#  ('2agpe141_p', '2AGPE141tipp'): -1.0,
#  ('2agpe141_c', '2AGPE141tipp'): 1.0,
#  ('2agpe160_p', '2AGPE160tipp'): -1.0,
#  ('2agpe160_c', '2AGPE160tipp'): 1.0,
#  ('tsul_e', 'EX_tsul_e'): -1.0,
#  ('eca4colipa_e', 'EX_eca4colipa_e'): -1.0,
#  ('ttdca_e', 'EX_ttdca_e'): -1.0,
#  ('2agpe161_p', '2AGPE161tipp'): -1.0,
#  ('2agpe161_c', '2AGPE161tipp'): 1.0,
#  ('2agpe180_p', '2AGPE180tipp'): -1.0,
#  ('2agpe180_c', '2AGPE180tipp'): 1.0,
#  ('2agpe181_p', '2AGPE181tipp'): -1.0,
#  ('2agpe181_c', '2AGPE181tipp'): 1.0,
#  ('2agpe120_c', '2AGPEAT120'): -1.0,
#  ('atp_c', '2AGPEAT120'): -1.0,
#  ('ddca_c', '2AGPEAT120'): -1.0,
#  ('amp_c', '2AGPEAT120'): 1.0,
#  ('pe120_c', '2AGPEAT120'): 1.0,
#  ('ppi_c', '2AGPEAT120'): 1.0,
#  ('ttdcea_e', 'EX_ttdcea_e'): -1.0,
#  ('enlipa_e', 'EX_enlipa_e'): -1.0,
#  ('2agpe140_c', '2AGPEAT140'): -1.0,
#  ('atp_c', '2AGPEAT140'): -1.0,
#  ('ttdca_c', '2AGPEAT140'): -1.0,
#  ('amp_c', '2AGPEAT140'): 1.0,
#  ('pe140_c', '2AGPEAT140'): 1.0,
#  ('ppi_c', '2AGPEAT140'): 1.0,
#  ('2agpe141_c', '2AGPEAT141'): -1.0,
#  ('atp_c', '2AGPEAT141'): -1.0,
#  ('ttdcea_c', '2AGPEAT141'): -1.0,
#  ('amp_c', '2AGPEAT141'): 1.0,
#  ('pe141_c', '2AGPEAT141'): 1.0,
#  ('ppi_c', '2AGPEAT141'): 1.0,
#  ('2agpe160_c', '2AGPEAT160'): -1.0,
#  ('atp_c', '2AGPEAT160'): -1.0,
#  ('hdca_c', '2AGPEAT160'): -1.0,
#  ('amp_c', '2AGPEAT160'): 1.0,
#  ('pe160_c', '2AGPEAT160'): 1.0,
#  ('ppi_c', '2AGPEAT160'): 1.0,
#  ('ttrcyc_e', 'EX_ttrcyc_e'): -1.0,
#  ('enter_e', 'EX_enter_e'): -1.0,
#  ('2agpe161_c', '2AGPEAT161'): -1.0,
#  ('atp_c', '2AGPEAT161'): -1.0,
#  ('hdcea_c', '2AGPEAT161'): -1.0,
#  ('amp_c', '2AGPEAT161'): 1.0,
#  ('pe161_c', '2AGPEAT161'): 1.0,
#  ('ppi_c', '2AGPEAT161'): 1.0,
#  ('etha_e', 'EX_etha_e'): -1.0,
#  ('2agpe180_c', '2AGPEAT180'): -1.0,
#  ('atp_c', '2AGPEAT180'): -1.0,
#  ('ocdca_c', '2AGPEAT180'): -1.0,
#  ('amp_c', '2AGPEAT180'): 1.0,
#  ('pe180_c', '2AGPEAT180'): 1.0,
#  ('ppi_c', '2AGPEAT180'): 1.0,
#  ('2agpe181_c', '2AGPEAT181'): -1.0,
#  ('atp_c', '2AGPEAT181'): -1.0,
#  ('ocdcea_c', '2AGPEAT181'): -1.0,
#  ('amp_c', '2AGPEAT181'): 1.0,
#  ('pe181_c', '2AGPEAT181'): 1.0,
#  ('ppi_c', '2AGPEAT181'): 1.0,
#  ('tungs_e', 'EX_tungs_e'): -1.0,
#  ('tym_e', 'EX_tym_e'): -1.0,
#  ('2agpg120_p', '2AGPG120tipp'): -1.0,
#  ('2agpg120_c', '2AGPG120tipp'): 1.0,
#  ('ethso3_e', 'EX_ethso3_e'): -1.0,
#  ('2agpg140_p', '2AGPG140tipp'): -1.0,
#  ('2agpg140_c', '2AGPG140tipp'): 1.0,
#  ('2agpg141_p', '2AGPG141tipp'): -1.0,
#  ('2agpg141_c', '2AGPG141tipp'): 1.0,
#  ('2agpg160_p', '2AGPG160tipp'): -1.0,
#  ('2agpg160_c', '2AGPG160tipp'): 1.0,
#  ('2agpg161_p', '2AGPG161tipp'): -1.0,
#  ('2agpg161_c', '2AGPG161tipp'): 1.0,
#  ('tyr__L_e', 'EX_tyr__L_e'): -1.0,
#  ('tyrp_e', 'EX_tyrp_e'): -1.0,
#  ('uacgam_e', 'EX_uacgam_e'): -1.0,
#  ('udpacgal_e', 'EX_udpacgal_e'): -1.0,
#  ('udpg_e', 'EX_udpg_e'): -1.0,
#  ('2agpg180_p', '2AGPG180tipp'): -1.0,
#  ('2agpg180_c', '2AGPG180tipp'): 1.0,
#  ('2agpg181_p', '2AGPG181tipp'): -1.0,
#  ('2agpg181_c', '2AGPG181tipp'): 1.0,
#  ('2agpg120_c', '2AGPGAT120'): -1.0,
#  ('atp_c', '2AGPGAT120'): -1.0,
#  ('ddca_c', '2AGPGAT120'): -1.0,
#  ('amp_c', '2AGPGAT120'): 1.0,
#  ('pg120_c', '2AGPGAT120'): 1.0,
#  ('ppi_c', '2AGPGAT120'): 1.0,
#  ('udpgal_e', 'EX_udpgal_e'): -1.0,
#  ('etoh_e', 'EX_etoh_e'): -1.0,
#  ('udpglcur_e', 'EX_udpglcur_e'): -1.0,
#  ('2agpg140_c', '2AGPGAT140'): -1.0,
#  ('atp_c', '2AGPGAT140'): -1.0,
#  ('ttdca_c', '2AGPGAT140'): -1.0,
#  ('amp_c', '2AGPGAT140'): 1.0,
#  ('pg140_c', '2AGPGAT140'): 1.0,
#  ('ppi_c', '2AGPGAT140'): 1.0,
#  ('2agpg141_c', '2AGPGAT141'): -1.0,
#  ('atp_c', '2AGPGAT141'): -1.0,
#  ('ttdcea_c', '2AGPGAT141'): -1.0,
#  ('amp_c', '2AGPGAT141'): 1.0,
#  ('pg141_c', '2AGPGAT141'): 1.0,
#  ('ppi_c', '2AGPGAT141'): 1.0,
#  ('2agpg160_c', '2AGPGAT160'): -1.0,
#  ('atp_c', '2AGPGAT160'): -1.0,
#  ('hdca_c', '2AGPGAT160'): -1.0,
#  ('amp_c', '2AGPGAT160'): 1.0,
#  ('pg160_c', '2AGPGAT160'): 1.0,
#  ('ppi_c', '2AGPGAT160'): 1.0,
#  ('2agpg161_c', '2AGPGAT161'): -1.0,
#  ('atp_c', '2AGPGAT161'): -1.0,
#  ('hdcea_c', '2AGPGAT161'): -1.0,
#  ('amp_c', '2AGPGAT161'): 1.0,
#  ('pg161_c', '2AGPGAT161'): 1.0,
#  ('ppi_c', '2AGPGAT161'): 1.0,
#  ('ump_e', 'EX_ump_e'): -1.0,
#  ('2agpg180_c', '2AGPGAT180'): -1.0,
#  ('atp_c', '2AGPGAT180'): -1.0,
#  ('ocdca_c', '2AGPGAT180'): -1.0,
#  ('amp_c', '2AGPGAT180'): 1.0,
#  ('pg180_c', '2AGPGAT180'): 1.0,
#  ('ppi_c', '2AGPGAT180'): 1.0,
#  ('f6p_e', 'EX_f6p_e'): -1.0,
#  ('2agpg181_c', '2AGPGAT181'): -1.0,
#  ('atp_c', '2AGPGAT181'): -1.0,
#  ('ocdcea_c', '2AGPGAT181'): -1.0,
#  ('amp_c', '2AGPGAT181'): 1.0,
#  ('pg181_c', '2AGPGAT181'): 1.0,
#  ('ppi_c', '2AGPGAT181'): 1.0,
#  ('ura_e', 'EX_ura_e'): -1.0,
#  ('2dhguln_c', '2DGULRGx'): -1.0,
#  ('h_c', '2DGULRGx'): -1.0,
#  ('nadh_c', '2DGULRGx'): -1.0,
#  ('glcn_c', '2DGULRGx'): 1.0,
#  ('nad_c', '2DGULRGx'): 1.0,
#  ('urea_e', 'EX_urea_e'): -1.0,
#  ('2dhguln_c', '2DGULRGy'): -1.0,
#  ('h_c', '2DGULRGy'): -1.0,
#  ('nadph_c', '2DGULRGy'): -1.0,
#  ('glcn_c', '2DGULRGy'): 1.0,
#  ('nadp_c', '2DGULRGy'): 1.0,
#  ('fald_e', 'EX_fald_e'): -1.0,
#  ('2dhguln_c', '2DGULRx'): -1.0,
#  ('h_c', '2DGULRx'): -1.0,
#  ('nadh_c', '2DGULRx'): -1.0,
#  ('idon__L_c', '2DGULRx'): 1.0,
#  ('nad_c', '2DGULRx'): 1.0,
#  ('2dhguln_c', '2DGULRy'): -1.0,
#  ('h_c', '2DGULRy'): -1.0,
#  ('nadph_c', '2DGULRy'): -1.0,
#  ('idon__L_c', '2DGULRy'): 1.0,
#  ('nadp_c', '2DGULRy'): 1.0,
#  ('uri_e', 'EX_uri_e'): -1.0,
#  ('2mahmp_c', '2MAHMP'): -1.0,
#  ('h2o_c', '2MAHMP'): -1.0,
#  ('4ampm_c', '2MAHMP'): 1.0,
#  ('h_c', '2MAHMP'): 1.0,
#  ('pi_c', '2MAHMP'): 1.0,
#  ('34dhpac_e', '34dhpactex'): -1.0,
#  ('34dhpac_p', '34dhpactex'): 1.0,
#  ('fe2_e', 'EX_fe2_e'): -1.0,
#  ('3amac_c', '3AMACHYD'): -1.0,
#  ('h2o_c', '3AMACHYD'): -1.0,
#  ('h_c', '3AMACHYD'): -1.0,
#  ('msa_c', '3AMACHYD'): 1.0,
#  ('nh4_c', '3AMACHYD'): 1.0,
#  ('3amp_e', '3AMPtex'): -1.0,
#  ('3amp_p', '3AMPtex'): 1.0,
#  ('3cmp_e', '3CMPtex'): -1.0,
#  ('3cmp_p', '3CMPtex'): 1.0,
#  ('3gmp_e', '3GMPtex'): -1.0,
#  ('3gmp_p', '3GMPtex'): 1.0,
#  ('fe3_e', 'EX_fe3_e'): -1.0,
#  ('3hdecACP_c', '3HAD100'): -1.0,
#  ('h2o_c', '3HAD100'): 1.0,
#  ('tdec2eACP_c', '3HAD100'): 1.0,
#  ('fe3dcit_e', 'EX_fe3dcit_e'): -1.0,
#  ('3hddecACP_c', '3HAD120'): -1.0,
#  ('h2o_c', '3HAD120'): 1.0,
#  ('tddec2eACP_c', '3HAD120'): 1.0,
#  ('dad_5_c', '5DOAN'): -1.0,
#  ('h2o_c', '5DOAN'): -1.0,
#  ('5drib_c', '5DOAN'): 1.0,
#  ('ade_c', '5DOAN'): 1.0,
#  ('fe3dhbzs_e', 'EX_fe3dhbzs_e'): -1.0,
#  ('5mtr_e', '5MTRtex'): -1.0,
#  ('5mtr_p', '5MTRtex'): 1.0,
#  ('5mtr_c', '5MTRtpp'): -1.0,
#  ('h_c', '5MTRtpp'): -1.0,
#  ('5mtr_p', '5MTRtpp'): 1.0,
#  ('h_p', '5MTRtpp'): 1.0,
#  ('3hcddec5eACP_c', '3HAD121'): -1.0,
#  ('h2o_c', '3HAD121'): 1.0,
#  ('t3c5ddeceACP_c', '3HAD121'): 1.0,
#  ('3hmrsACP_c', '3HAD140'): -1.0,
#  ('h2o_c', '3HAD140'): 1.0,
#  ('tmrs2eACP_c', '3HAD140'): 1.0,
#  ('ru5p__D_c', 'A5PISO'): -1.0,
#  ('ara5p_c', 'A5PISO'): 1.0,
#  ('fe3hox_e', 'EX_fe3hox_e'): -1.0,
#  ('ACP_c', 'AACPS1'): -1.0,
#  ('atp_c', 'AACPS1'): -1.0,
#  ('ttdca_c', 'AACPS1'): -1.0,
#  ('amp_c', 'AACPS1'): 1.0,
#  ('myrsACP_c', 'AACPS1'): 1.0,
#  ('ppi_c', 'AACPS1'): 1.0,
#  ('ACP_c', 'AACPS2'): -1.0,
#  ('atp_c', 'AACPS2'): -1.0,
#  ('ttdcea_c', 'AACPS2'): -1.0,
#  ('amp_c', 'AACPS2'): 1.0,
#  ('ppi_c', 'AACPS2'): 1.0,
#  ('tdeACP_c', 'AACPS2'): 1.0,
#  ('3hcmrs7eACP_c', '3HAD141'): -1.0,
#  ('h2o_c', '3HAD141'): 1.0,
#  ('t3c7mrseACP_c', '3HAD141'): 1.0,
#  ('fe3hox_un_e', 'EX_fe3hox_un_e'): -1.0,
#  ('ACP_c', 'AACPS3'): -1.0,
#  ('atp_c', 'AACPS3'): -1.0,
#  ('hdca_c', 'AACPS3'): -1.0,
#  ('amp_c', 'AACPS3'): 1.0,
#  ('palmACP_c', 'AACPS3'): 1.0,
#  ('ppi_c', 'AACPS3'): 1.0,
#  ('ACP_c', 'AACPS4'): -1.0,
#  ('atp_c', 'AACPS4'): -1.0,
#  ('hdcea_c', 'AACPS4'): -1.0,
#  ('amp_c', 'AACPS4'): 1.0,
#  ('hdeACP_c', 'AACPS4'): 1.0,
#  ('ppi_c', 'AACPS4'): 1.0,
#  ('ACP_c', 'AACPS5'): -1.0,
#  ('atp_c', 'AACPS5'): -1.0,
#  ('ocdcea_c', 'AACPS5'): -1.0,
#  ('amp_c', 'AACPS5'): 1.0,
#  ('octeACP_c', 'AACPS5'): 1.0,
#  ('ppi_c', 'AACPS5'): 1.0,
#  ('3hpalmACP_c', '3HAD160'): -1.0,
#  ('h2o_c', '3HAD160'): 1.0,
#  ('tpalm2eACP_c', '3HAD160'): 1.0,
#  ('ACP_c', 'AACPS6'): -1.0,
#  ('atp_c', 'AACPS6'): -1.0,
#  ('ocdca_c', 'AACPS6'): -1.0,
#  ('amp_c', 'AACPS6'): 1.0,
#  ('ocdcaACP_c', 'AACPS6'): 1.0,
#  ('ppi_c', 'AACPS6'): 1.0,
#  ('fecrm_e', 'EX_fecrm_e'): -1.0,
#  ('ACP_c', 'AACPS7'): -1.0,
#  ('atp_c', 'AACPS7'): -1.0,
#  ('ddca_c', 'AACPS7'): -1.0,
#  ('amp_c', 'AACPS7'): 1.0,
#  ('ddcaACP_c', 'AACPS7'): 1.0,
#  ('ppi_c', 'AACPS7'): 1.0,
#  ('3hcpalm9eACP_c', '3HAD161'): -1.0,
#  ('h2o_c', '3HAD161'): 1.0,
#  ('t3c9palmeACP_c', '3HAD161'): 1.0,
#  ('ACP_c', 'AACPS8'): -1.0,
#  ('atp_c', 'AACPS8'): -1.0,
#  ('dca_c', 'AACPS8'): -1.0,
#  ('amp_c', 'AACPS8'): 1.0,
#  ('dcaACP_c', 'AACPS8'): 1.0,
#  ('ppi_c', 'AACPS8'): 1.0,
#  ('fecrm_un_e', 'EX_fecrm_un_e'): -1.0,
#  ('ACP_c', 'AACPS9'): -1.0,
#  ('atp_c', 'AACPS9'): -1.0,
#  ('octa_c', 'AACPS9'): -1.0,
#  ('amp_c', 'AACPS9'): 1.0,
#  ('ocACP_c', 'AACPS9'): 1.0,
#  ('ppi_c', 'AACPS9'): 1.0,
#  ('3hoctaACP_c', '3HAD180'): -1.0,
#  ('h2o_c', '3HAD180'): 1.0,
#  ('toctd2eACP_c', '3HAD180'): 1.0,
#  ('3hcvac11eACP_c', '3HAD181'): -1.0,
#  ('h2o_c', '3HAD181'): 1.0,
#  ('t3c11vaceACP_c', '3HAD181'): 1.0,
#  ('aact_c', 'AACTOOR'): -1.0,
#  ('h2o_c', 'AACTOOR'): -1.0,
#  ('o2_c', 'AACTOOR'): -1.0,
#  ('h2o2_c', 'AACTOOR'): 1.0,
#  ('mthgxl_c', 'AACTOOR'): 1.0,
#  ('nh4_c', 'AACTOOR'): 1.0,
#  ('dtdp4aaddg_c', 'AADDGT'): -1.0,
#  ('unagamu_c', 'AADDGT'): -1.0,
#  ('dtdp_c', 'AADDGT'): 1.0,
#  ('h_c', 'AADDGT'): 1.0,
#  ('unagamuf_c', 'AADDGT'): 1.0,
#  ('14glucan_c', 'AAMYL'): -1.0,
#  ('malthx_c', 'AAMYL'): 1.0,
#  ('14glucan_p', 'AAMYLpp'): -1.0,
#  ('malthx_p', 'AAMYLpp'): 1.0,
#  ('arbt6p_c', 'AB6PGH'): -1.0,
#  ('h2o_c', 'AB6PGH'): -1.0,
#  ('g6p_c', 'AB6PGH'): 1.0,
#  ('hqn_c', 'AB6PGH'): 1.0,
#  ('4abut_c', 'ABTA'): -1.0,
#  ('akg_c', 'ABTA'): -1.0,
#  ('glu__L_c', 'ABTA'): 1.0,
#  ('sucsal_c', 'ABTA'): 1.0,
#  ('4abutn_c', 'ABUTD'): -1.0,
#  ('h2o_c', 'ABUTD'): -1.0,
#  ('nad_c', 'ABUTD'): -1.0,
#  ('4abut_c', 'ABUTD'): 1.0,
#  ('h_c', 'ABUTD'): 2.0,
#  ('nadh_c', 'ABUTD'): 1.0,
#  ('3haACP_c', '3HAD40'): -1.0,
#  ('but2eACP_c', '3HAD40'): 1.0,
#  ('h2o_c', '3HAD40'): 1.0,
#  ('3hhexACP_c', '3HAD60'): -1.0,
#  ('h2o_c', '3HAD60'): 1.0,
#  ('thex2eACP_c', '3HAD60'): 1.0,
#  ('3hoctACP_c', '3HAD80'): -1.0,
#  ('h2o_c', '3HAD80'): 1.0,
#  ('toct2eACP_c', '3HAD80'): 1.0,
#  ('3hcinnm_c', '3HCINNMH'): -1.0,
#  ('h_c', '3HCINNMH'): -1.0,
#  ('nadh_c', '3HCINNMH'): -1.0,
#  ('o2_c', '3HCINNMH'): -1.0,
#  ('dhcinnm_c', '3HCINNMH'): 1.0,
#  ('h2o_c', '3HCINNMH'): 1.0,
#  ('nad_c', '3HCINNMH'): 1.0,
#  ('3hpppn_c', '3HPPPNH'): -1.0,
#  ('h_c', '3HPPPNH'): -1.0,
#  ('nadh_c', '3HPPPNH'): -1.0,
#  ('o2_c', '3HPPPNH'): -1.0,
#  ('dhpppn_c', '3HPPPNH'): 1.0,
#  ('h2o_c', '3HPPPNH'): 1.0,
#  ('nad_c', '3HPPPNH'): 1.0,
#  ('4abut_p', 'ABUTt2pp'): -1.0,
#  ('h_p', 'ABUTt2pp'): -1.0,
#  ('4abut_c', 'ABUTt2pp'): 1.0,
#  ('h_c', 'ABUTt2pp'): 1.0,
#  ('feenter_e', 'EX_feenter_e'): -1.0,
#  ('4abut_e', 'ABUTtex'): -1.0,
#  ('4abut_p', 'ABUTtex'): 1.0,
#  ('3hpp_e', '3HPPtex'): -1.0,
#  ('3hpp_p', '3HPPtex'): 1.0,
#  ('3hpp_c', '3HPPtpp'): -1.0,
#  ('h_c', '3HPPtpp'): -1.0,
#  ('3hpp_p', '3HPPtpp'): 1.0,
#  ('h_p', '3HPPtpp'): 1.0,
#  ('acac_c', 'ACACCT'): -1.0,
#  ('accoa_c', 'ACACCT'): -1.0,
#  ('aacoa_c', 'ACACCT'): 1.0,
#  ('ac_c', 'ACACCT'): 1.0,
#  ('accoa_c', 'ACACT1r'): -2.0,
#  ('aacoa_c', 'ACACT1r'): 1.0,
#  ('coa_c', 'ACACT1r'): 1.0,
#  ('3dhguln_c', '3KGK'): -1.0,
#  ('atp_c', '3KGK'): -1.0,
#  ('3dhgulnp_c', '3KGK'): 1.0,
#  ('adp_c', '3KGK'): 1.0,
#  ('h_c', '3KGK'): 1.0,
#  ('accoa_c', 'ACACT2r'): -1.0,
#  ('btcoa_c', 'ACACT2r'): -1.0,
#  ('3ohcoa_c', 'ACACT2r'): 1.0,
#  ('coa_c', 'ACACT2r'): 1.0,
#  ('feoxam_e', 'EX_feoxam_e'): -1.0,
#  ('accoa_c', 'ACACT3r'): -1.0,
#  ('hxcoa_c', 'ACACT3r'): -1.0,
#  ('3oocoa_c', 'ACACT3r'): 1.0,
#  ('coa_c', 'ACACT3r'): 1.0,
#  ('accoa_c', 'ACACT4r'): -1.0,
#  ('occoa_c', 'ACACT4r'): -1.0,
#  ('3odcoa_c', 'ACACT4r'): 1.0,
#  ('coa_c', 'ACACT4r'): 1.0,
#  ('3ump_p', '3NTD2pp'): -1.0,
#  ('h2o_p', '3NTD2pp'): -1.0,
#  ('pi_p', '3NTD2pp'): 1.0,
#  ('uri_p', '3NTD2pp'): 1.0,
#  ('3cmp_p', '3NTD4pp'): -1.0,
#  ('h2o_p', '3NTD4pp'): -1.0,
#  ('cytd_p', '3NTD4pp'): 1.0,
#  ('pi_p', '3NTD4pp'): 1.0,
#  ('feoxam_un_e', 'EX_feoxam_un_e'): -1.0,
#  ('accoa_c', 'ACACT5r'): -1.0,
#  ('dcacoa_c', 'ACACT5r'): -1.0,
#  ('3oddcoa_c', 'ACACT5r'): 1.0,
#  ('coa_c', 'ACACT5r'): 1.0,
#  ('for_e', 'EX_for_e'): -1.0,
#  ('accoa_c', 'ACACT6r'): -1.0,
#  ('ddcacoa_c', 'ACACT6r'): -1.0,
#  ('3otdcoa_c', 'ACACT6r'): 1.0,
#  ('coa_c', 'ACACT6r'): 1.0,
#  ('3amp_p', '3NTD7pp'): -1.0,
#  ('h2o_p', '3NTD7pp'): -1.0,
#  ('adn_p', '3NTD7pp'): 1.0,
#  ('pi_p', '3NTD7pp'): 1.0,
#  ('3gmp_p', '3NTD9pp'): -1.0,
#  ('h2o_p', '3NTD9pp'): -1.0,
#  ('gsn_p', '3NTD9pp'): 1.0,
#  ('pi_p', '3NTD9pp'): 1.0,
#  ('fru_e', 'EX_fru_e'): -1.0,
#  ('3odecACP_c', '3OAR100'): -1.0,
#  ('h_c', '3OAR100'): -1.0,
#  ('nadph_c', '3OAR100'): -1.0,
#  ('3hdecACP_c', '3OAR100'): 1.0,
#  ('nadp_c', '3OAR100'): 1.0,
#  ('accoa_c', 'ACACT7r'): -1.0,
#  ('tdcoa_c', 'ACACT7r'): -1.0,
#  ('3ohdcoa_c', 'ACACT7r'): 1.0,
#  ('coa_c', 'ACACT7r'): 1.0,
#  ('frulys_e', 'EX_frulys_e'): -1.0,
#  ('3ohodcoa_c', 'ACACT8r'): -1.0,
#  ('coa_c', 'ACACT8r'): -1.0,
#  ('accoa_c', 'ACACT8r'): 1.0,
#  ('pmtcoa_c', 'ACACT8r'): 1.0,
#  ('acac_p', 'ACACt2pp'): -1.0,
#  ('h_p', 'ACACt2pp'): -1.0,
#  ('acac_c', 'ACACt2pp'): 1.0,
#  ('h_c', 'ACACt2pp'): 1.0,
#  ('acac_e', 'ACACtex'): -1.0,
#  ('acac_p', 'ACACtex'): 1.0,
#  ('3oddecACP_c', '3OAR120'): -1.0,
#  ('h_c', '3OAR120'): -1.0,
#  ('nadph_c', '3OAR120'): -1.0,
#  ('3hddecACP_c', '3OAR120'): 1.0,
#  ('nadp_c', '3OAR120'): 1.0,
#  ('3ocddec5eACP_c', '3OAR121'): -1.0,
#  ('h_c', '3OAR121'): -1.0,
#  ('nadph_c', '3OAR121'): -1.0,
#  ('3hcddec5eACP_c', '3OAR121'): 1.0,
#  ('nadp_c', '3OAR121'): 1.0,
#  ('3omrsACP_c', '3OAR140'): -1.0,
#  ('h_c', '3OAR140'): -1.0,
#  ('nadph_c', '3OAR140'): -1.0,
#  ('3hmrsACP_c', '3OAR140'): 1.0,
#  ('nadp_c', '3OAR140'): 1.0,
#  ('acald_c', 'ACALD'): -1.0,
#  ('coa_c', 'ACALD'): -1.0,
#  ('nad_c', 'ACALD'): -1.0,
#  ('accoa_c', 'ACALD'): 1.0,
#  ('h_c', 'ACALD'): 1.0,
#  ('nadh_c', 'ACALD'): 1.0,
#  ('3ocmrs7eACP_c', '3OAR141'): -1.0,
#  ('h_c', '3OAR141'): -1.0,
#  ('nadph_c', '3OAR141'): -1.0,
#  ('3hcmrs7eACP_c', '3OAR141'): 1.0,
#  ('nadp_c', '3OAR141'): 1.0,
#  ('fruur_e', 'EX_fruur_e'): -1.0,
#  ('3opalmACP_c', '3OAR160'): -1.0,
#  ('h_c', '3OAR160'): -1.0,
#  ('nadph_c', '3OAR160'): -1.0,
#  ('3hpalmACP_c', '3OAR160'): 1.0,
#  ('nadp_c', '3OAR160'): 1.0,
#  ('acald_e', 'ACALDtex'): -1.0,
#  ('acald_p', 'ACALDtex'): 1.0,
#  ('fuc__L_e', 'EX_fuc__L_e'): -1.0,
#  ('3ocpalm9eACP_c', '3OAR161'): -1.0,
#  ('h_c', '3OAR161'): -1.0,
#  ('nadph_c', '3OAR161'): -1.0,
#  ('3hcpalm9eACP_c', '3OAR161'): 1.0,
#  ('nadp_c', '3OAR161'): 1.0,
#  ('fum_e', 'EX_fum_e'): -1.0,
#  ('acald_p', 'ACALDtpp'): -1.0,
#  ('acald_c', 'ACALDtpp'): 1.0,
#  ('3ooctdACP_c', '3OAR180'): -1.0,
#  ('h_c', '3OAR180'): -1.0,
#  ('nadph_c', '3OAR180'): -1.0,
#  ('3hoctaACP_c', '3OAR180'): 1.0,
#  ('nadp_c', '3OAR180'): 1.0,
#  ('fusa_e', 'EX_fusa_e'): -1.0,
#  ('accoa_c', 'ACANTHAT'): -1.0,
#  ('anth_c', 'ACANTHAT'): -1.0,
#  ('acanth_c', 'ACANTHAT'): 1.0,
#  ('coa_c', 'ACANTHAT'): 1.0,
#  ('3ocvac11eACP_c', '3OAR181'): -1.0,
#  ('h_c', '3OAR181'): -1.0,
#  ('nadph_c', '3OAR181'): -1.0,
#  ('3hcvac11eACP_c', '3OAR181'): 1.0,
#  ('nadp_c', '3OAR181'): 1.0,
#  ('adocbip_c', 'ACBIPGT'): -1.0,
#  ('gtp_c', 'ACBIPGT'): -1.0,
#  ('h_c', 'ACBIPGT'): -1.0,
#  ('agdpcbi_c', 'ACBIPGT'): 1.0,
#  ('ppi_c', 'ACBIPGT'): 1.0,
#  ('g1p_e', 'EX_g1p_e'): -1.0,
#  ...}

# %%
simulator.run_FBA()
# Out:
# (2,
#  0.982371812726977,
#  {'EX_cm_e': 0.0,
#   'EX_cmp_e': 0.0,
#   'EX_co2_e': 19.675222635663204,
#   'EX_cobalt2_e': -2.4559295297876815e-05,
#   'DM_4crsol_c': 0.00021906891423811587,
#   'DM_5drib_c': 0.00022103365786356984,
#   'DM_aacald_c': 0.0,
#   'DM_amob_c': 1.964743625453954e-06,
#   'DM_mththf_c': 0.00044010257210168574,
#   'EX_colipa_e': 0.0,
#   'DM_oxam_c': 0.0,
#   'EX_glc__D_e': -10.0,
#   'EX_glcn_e': 0.0,
#   'BIOMASS_Ec_iJO1366_WT_53p95M': 0.0,
#   'EX_glcr_e': 0.0,
#   'EX_colipap_e': 0.0,
#   'EX_glcur_e': 0.0,
#   'EX_glcur1p_e': 0.0,
#   'BIOMASS_Ec_iJO1366_core_53p95M': 0.982371812726977,
#   'EX_12ppd__R_e': 0.0,
#   'EX_gln__L_e': 0.0,
#   'EX_cpgn_e': 0.0,
#   'EX_glu__L_e': 0.0,
#   'EX_gly_e': 0.0,
#   'EX_glyald_e': 0.0,
#   'EX_glyb_e': 0.0,
#   'EX_glyc_e': 0.0,
#   'EX_12ppd__S_e': 0.0,
#   'EX_14glucan_e': 0.0,
#   'EX_cpgn_un_e': 0.0,
#   'EX_15dap_e': 0.0,
#   'EX_glyc__R_e': 0.0,
#   'EX_glyc2p_e': 0.0,
#   'EX_23camp_e': 0.0,
#   'EX_23ccmp_e': 0.0,
#   'EX_23cgmp_e': 0.0,
#   'EX_23cump_e': 0.0,
#   'EX_23dappa_e': 0.0,
#   'EX_26dap__M_e': 0.0,
#   'EX_glyc3p_e': 0.0,
#   'EX_glyclt_e': 0.0,
#   'EX_gmp_e': 0.0,
#   'EX_gsn_e': 0.0,
#   'EX_gthox_e': 0.0,
#   'EX_gthrd_e': 0.0,
#   'EX_gtp_e': 0.0,
#   'EX_gua_e': 0.0,
#   'EX_h_e': 9.026260125595059,
#   'EX_h2_e': 0.0,
#   'EX_h2o_e': 45.619430370034934,
#   'EX_h2o2_e': 0.0,
#   'EX_h2s_e': 0.0,
#   'EX_hacolipa_e': 0.0,
#   'EX_halipa_e': 0.0,
#   'EX_hdca_e': 0.0,
#   'EX_hdcea_e': 0.0,
#   'EX_hg2_e': 0.0,
#   'EX_his__L_e': 0.0,
#   'EX_2ddglcn_e': 0.0,
#   'EX_34dhpac_e': 0.0,
#   'EX_3amp_e': 0.0,
#   'EX_3cmp_e': 0.0,
#   'EX_3gmp_e': 0.0,
#   'EX_3hcinnm_e': 0.0,
#   'EX_3hpp_e': 0.0,
#   'EX_3hpppn_e': 0.0,
#   'EX_hom__L_e': 0.0,
#   'EX_hxa_e': 0.0,
#   'EX_hxan_e': 0.0,
#   'EX_idon__L_e': 0.0,
#   'EX_3ump_e': 0.0,
#   'EX_4abut_e': 0.0,
#   'EX_4hoxpacd_e': 0.0,
#   'EX_5dglcn_e': 0.0,
#   'EX_5mtr_e': 0.0,
#   'EX_LalaDglu_e': 0.0,
#   'EX_ile__L_e': 0.0,
#   'EX_imp_e': 0.0,
#   'EX_indole_e': 0.0,
#   'EX_inost_e': 0.0,
#   'EX_ins_e': 0.0,
#   'EX_isetac_e': 0.0,
#   'EX_k_e': -0.19175210124160458,
#   'EX_LalaDgluMdap_e': 0.0,
#   'EX_LalaDgluMdapDala_e': 0.0,
#   'EX_LalaLglu_e': 0.0,
#   'EX_kdo2lipid4_e': 0.0,
#   'EX_ac_e': 0.0,
#   'EX_crn_e': 0.0,
#   'EX_acac_e': 0.0,
#   'EX_acald_e': 0.0,
#   'EX_lac__D_e': 0.0,
#   'EX_lac__L_e': 0.0,
#   'EX_crn__D_e': 0.0,
#   'EX_lcts_e': 0.0,
#   'EX_acgal_e': 0.0,
#   'EX_acgal1p_e': 0.0,
#   'EX_acgam_e': 0.0,
#   'EX_leu__L_e': 0.0,
#   'EX_csn_e': 0.0,
#   'EX_acgam1p_e': 0.0,
#   'EX_acmana_e': 0.0,
#   'EX_acmum_e': 0.0,
#   'EX_lipa_e': 0.0,
#   'EX_cu_e': 0.0,
#   'EX_lipa_cold_e': 0.0,
#   'EX_acnam_e': 0.0,
#   'EX_acolipa_e': 0.0,
#   'EX_cu2_e': -0.0006965016152662429,
#   'EX_acser_e': 0.0,
#   'EX_ade_e': 0.0,
#   'EX_adn_e': 0.0,
#   'EX_adocbl_e': 0.0,
#   'EX_ag_e': 0.0,
#   'EX_lipoate_e': 0.0,
#   'EX_lys__L_e': 0.0,
#   'EX_lyx__L_e': 0.0,
#   'EX_mal__D_e': 0.0,
#   'EX_agm_e': 0.0,
#   'EX_akg_e': 0.0,
#   'EX_cyan_e': 0.0,
#   'EX_ala_B_e': 0.0,
#   'EX_ala__D_e': 0.0,
#   'EX_ala__L_e': 0.0,
#   'EX_alaala_e': 0.0,
#   'EX_all__D_e': 0.0,
#   'EX_alltn_e': 0.0,
#   'EX_amp_e': 0.0,
#   'EX_anhgm_e': 0.0,
#   'EX_arab__L_e': 0.0,
#   'EX_mal__L_e': 0.0,
#   'EX_malt_e': 0.0,
#   'EX_malthx_e': 0.0,
#   'EX_maltpt_e': 0.0,
#   'EX_malttr_e': 0.0,
#   'EX_maltttr_e': 0.0,
#   'EX_man_e': 0.0,
#   'EX_cynt_e': 0.0,
#   'EX_man6p_e': 0.0,
#   'EX_manglyc_e': 0.0,
#   'EX_melib_e': 0.0,
#   'EX_cys__D_e': 0.0,
#   'EX_meoh_e': 1.964743625453954e-06,
#   'EX_met__D_e': 0.0,
#   'EX_arbt_e': 0.0,
#   'EX_arbtn_e': 0.0,
#   'EX_arbtn_fe3_e': 0.0,
#   'EX_met__L_e': 0.0,
#   'EX_cys__L_e': 0.0,
#   'EX_metsox_R__L_e': 0.0,
#   'EX_metsox_S__L_e': 0.0,
#   'EX_mg2_e': -0.008522075475411839,
#   'EX_mincyc_e': 0.0,
#   'EX_minohp_e': 0.0,
#   'EX_mmet_e': 0.0,
#   'EX_arg__L_e': 0.0,
#   'EX_ascb__L_e': 0.0,
#   'EX_asn__L_e': 0.0,
#   'EX_aso3_e': 0.0,
#   'EX_asp__L_e': 0.0,
#   'EX_btn_e': 0.0,
#   'EX_but_e': 0.0,
#   'EX_mn2_e': -0.0006788189225517272,
#   'EX_mnl_e': 0.0,
#   'EX_mobd_e': -0.00012672596380980394,
#   'EX_mso3_e': 0.0,
#   'EX_n2o_e': 0.0,
#   'EX_na1_e': 0.0,
#   'EX_nac_e': 0.0,
#   'EX_nh4_e': -10.610425051825132,
#   'EX_butso3_e': 0.0,
#   'EX_ca2_e': -0.005113245285201629,
#   'EX_cbi_e': 0.0,
#   'EX_cytd_e': 0.0,
#   'EX_cbl1_e': 0.0,
#   'EX_cd2_e': 0.0,
#   'EX_cgly_e': 0.0,
#   'EX_ni2_e': -0.0003173060955532492,
#   'EX_nmn_e': 0.0,
#   'EX_no_e': 0.0,
#   'EX_no2_e': 0.0,
#   'EX_no3_e': 0.0,
#   'EX_novbcn_e': 0.0,
#   'EX_o16a4colipa_e': 0.0,
#   'EX_o2_e': -17.578933530254176,
#   'EX_o2s_e': 0.0,
#   'EX_ocdca_e': 0.0,
#   'EX_ocdcea_e': 0.0,
#   'EX_octa_e': 0.0,
#   'EX_orn_e': 0.0,
#   'EX_orot_e': 0.0,
#   'EX_pacald_e': 0.0,
#   'EX_peamn_e': 0.0,
#   'EX_phe__L_e': 0.0,
#   'EX_pheme_e': 0.0,
#   'EX_chol_e': 0.0,
#   'EX_chtbs_e': 0.0,
#   'EX_cit_e': 0.0,
#   'EX_cl_e': -0.005113245285201629,
#   'EX_pi_e': -0.9476263040827462,
#   'EX_dad_2_e': 0.0,
#   'EX_pnto__R_e': 0.0,
#   'EX_ppa_e': 0.0,
#   'EX_damp_e': 0.0,
#   'EX_ppal_e': 0.0,
#   'EX_dca_e': 0.0,
#   'EX_pppn_e': 0.0,
#   'EX_ppt_e': 0.0,
#   'EX_dcmp_e': 0.0,
#   'EX_pro__L_e': 0.0,
#   'EX_dcyt_e': 0.0,
#   'EX_progly_e': 0.0,
#   'EX_psclys_e': 0.0,
#   'EX_ddca_e': 0.0,
#   'EX_pser__L_e': 0.0,
#   'EX_ptrc_e': 0.0,
#   'EX_dgmp_e': 0.0,
#   'EX_dgsn_e': 0.0,
#   'EX_val__L_e': 0.0,
#   'EX_xan_e': 0.0,
#   'EX_dha_e': 0.0,
#   'EX_xmp_e': 0.0,
#   'EX_dimp_e': 0.0,
#   'EX_din_e': 0.0,
#   'EX_xtsn_e': 0.0,
#   'EX_pydam_e': 0.0,
#   'EX_xyl__D_e': 0.0,
#   'EX_xylu__L_e': 0.0,
#   'EX_zn2_e': -0.00033498878815407807,
#   '12DGR120tipp': 0.0,
#   '12DGR140tipp': 0.0,
#   '12DGR141tipp': 0.0,
#   '12DGR160tipp': 0.0,
#   '12DGR161tipp': 0.0,
#   '12DGR180tipp': 0.0,
#   'EX_pydx_e': 0.0,
#   'EX_pydxn_e': 0.0,
#   'EX_pyr_e': 0.0,
#   'EX_quin_e': 0.0,
#   'EX_r5p_e': 0.0,
#   'EX_rfamp_e': 0.0,
#   'EX_rib__D_e': 0.0,
#   'EX_rmn_e': 0.0,
#   'EX_sbt__D_e': 0.0,
#   'EX_sel_e': 0.0,
#   'EX_ser__D_e': 0.0,
#   'EX_ser__L_e': 0.0,
#   'EX_skm_e': 0.0,
#   '12DGR181tipp': 0.0,
#   '12PPDRtex': 0.0,
#   '12PPDRtpp': 0.0,
#   'EX_dms_e': 0.0,
#   '12PPDStex': 0.0,
#   '12PPDStpp': 0.0,
#   '14GLUCANabcpp': 0.0,
#   'EX_slnt_e': 0.0,
#   'EX_so2_e': 0.0,
#   'EX_so3_e': 0.0,
#   'EX_dmso_e': 0.0,
#   'EX_so4_e': -0.24776399488791867,
#   'EX_spmd_e': 0.0,
#   'EX_succ_e': 0.0,
#   '14GLUCANtexi': 0.0,
#   '23CAMPtex': 0.0,
#   '23CCMPtex': 0.0,
#   'EX_sucr_e': 0.0,
#   'EX_sulfac_e': 0.0,
#   '23CGMPtex': 0.0,
#   'EX_tartr__D_e': 0.0,
#   '23CUMPtex': 0.0,
#   'EX_dopa_e': 0.0,
#   '23DAPPAt2pp': 0.0,
#   '23DAPPAtex': 0.0,
#   '23PDE2pp': 0.0,
#   '23PDE4pp': 0.0,
#   'EX_tartr__L_e': 0.0,
#   'EX_taur_e': 0.0,
#   'EX_tcynt_e': 0.0,
#   '23PDE7pp': 0.0,
#   '23PDE9pp': 0.0,
#   'EX_doxrbcn_e': 0.0,
#   '26DAHtex': 0.0,
#   '2AGPA120tipp': 0.0,
#   'EX_thm_e': 0.0,
#   'EX_thr__L_e': 0.0,
#   'EX_dtmp_e': 0.0,
#   'EX_thrp_e': 0.0,
#   '2AGPA140tipp': 0.0,
#   '2AGPA141tipp': 0.0,
#   'EX_thym_e': 0.0,
#   'EX_dump_e': 0.0,
#   'EX_thymd_e': 0.0,
#   '2AGPA160tipp': 0.0,
#   '2AGPA161tipp': 0.0,
#   'EX_tma_e': 0.0,
#   'EX_duri_e': 0.0,
#   'EX_tmao_e': 0.0,
#   'EX_tre_e': 0.0,
#   'EX_trp__L_e': 0.0,
#   '2AGPA180tipp': 0.0,
#   '2AGPA181tipp': 0.0,
#   '2AGPE120tipp': 0.0,
#   '2AGPE140tipp': 0.0,
#   '2AGPE141tipp': 0.0,
#   '2AGPE160tipp': 0.0,
#   'EX_tsul_e': 0.0,
#   'EX_eca4colipa_e': 0.0,
#   'EX_ttdca_e': 0.0,
#   '2AGPE161tipp': 0.0,
#   '2AGPE180tipp': 0.0,
#   '2AGPE181tipp': 0.0,
#   '2AGPEAT120': 0.0,
#   'EX_ttdcea_e': 0.0,
#   'EX_enlipa_e': 0.0,
#   '2AGPEAT140': 0.0,
#   '2AGPEAT141': 0.0,
#   '2AGPEAT160': 0.0,
#   'EX_ttrcyc_e': 0.0,
#   'EX_enter_e': 0.0,
#   '2AGPEAT161': 0.0,
#   'EX_etha_e': 0.0,
#   '2AGPEAT180': 0.0,
#   '2AGPEAT181': 0.0,
#   'EX_tungs_e': 0.0,
#   'EX_tym_e': 0.0,
#   '2AGPG120tipp': 0.0,
#   'EX_ethso3_e': 0.0,
#   '2AGPG140tipp': 0.0,
#   '2AGPG141tipp': 0.0,
#   '2AGPG160tipp': 0.0,
#   '2AGPG161tipp': 0.0,
#   'EX_tyr__L_e': 0.0,
#   'EX_tyrp_e': 0.0,
#   'EX_uacgam_e': 0.0,
#   'EX_udpacgal_e': 0.0,
#   'EX_udpg_e': 0.0,
#   '2AGPG180tipp': 0.0,
#   '2AGPG181tipp': 0.0,
#   '2AGPGAT120': 0.0,
#   'EX_udpgal_e': 0.0,
#   'EX_etoh_e': 0.0,
#   'EX_udpglcur_e': 0.0,
#   '2AGPGAT140': 0.0,
#   '2AGPGAT141': 0.0,
#   '2AGPGAT160': 0.0,
#   '2AGPGAT161': 0.0,
#   'EX_ump_e': 0.0,
#   '2AGPGAT180': 0.0,
#   'EX_f6p_e': 0.0,
#   '2AGPGAT181': 0.0,
#   'EX_ura_e': 0.0,
#   '2DGULRGx': 0.0,
#   'EX_urea_e': 0.0,
#   '2DGULRGy': 0.0,
#   'EX_fald_e': 0.0,
#   '2DGULRx': 0.0,
#   '2DGULRy': 0.0,
#   'EX_uri_e': 0.0,
#   '2MAHMP': 0.0,
#   '34dhpactex': 0.0,
#   'EX_fe2_e': -0.015777873684214683,
#   '3AMACHYD': 0.0,
#   '3AMPtex': 0.0,
#   '3CMPtex': 0.0,
#   '3GMPtex': 0.0,
#   'EX_fe3_e': 0.0,
#   '3HAD100': 0.0,
#   'EX_fe3dcit_e': 0.0,
#   '3HAD120': 0.0,
#   '5DOAN': 0.00022103365786356984,
#   'EX_fe3dhbzs_e': 0.0,
#   '5MTRtex': 0.0,
#   '5MTRtpp': 0.0,
#   '3HAD121': 0.0,
#   '3HAD140': 0.0,
#   'A5PISO': 0.03822605197683515,
#   'EX_fe3hox_e': 0.0,
#   'AACPS1': 0.0,
#   'AACPS2': 0.0,
#   '3HAD141': 0.0,
#   'EX_fe3hox_un_e': 0.0,
#   'AACPS3': 0.1253781497147186,
#   'AACPS4': 0.14777622704489368,
#   'AACPS5': 0.0,
#   '3HAD160': 0.0,
#   'AACPS6': 0.0,
#   'EX_fecrm_e': 0.0,
#   'AACPS7': 0.07645210395366427,
#   '3HAD161': 0.0,
#   'AACPS8': 0.0,
#   'EX_fecrm_un_e': 0.0,
#   'AACPS9': 0.0,
#   '3HAD180': 0.0,
#   '3HAD181': 0.0,
#   'AACTOOR': 0.0,
#   'AADDGT': 0.0,
#   'AAMYL': 0.0,
#   'AAMYLpp': 0.0,
#   'AB6PGH': 0.0,
#   'ABTA': 0.0,
#   'ABUTD': 0.0,
#   '3HAD40': 0.0,
#   '3HAD60': 0.0,
#   '3HAD80': 0.0,
#   '3HCINNMH': 0.0,
#   '3HPPPNH': 0.0,
#   'ABUTt2pp': 1000.0,
#   'EX_feenter_e': 0.0,
#   'ABUTtex': 0.0,
#   '3HPPtex': 0.0,
#   '3HPPtpp': 0.0,
#   'ACACCT': 0.0,
#   'ACACT1r': 0.34960648071330525,
#   '3KGK': 0.0,
#   'ACACT2r': 0.34960648071330525,
#   'EX_feoxam_e': 0.0,
#   'ACACT3r': 0.34960648071330525,
#   'ACACT4r': 0.34960648071330525,
#   '3NTD2pp': 0.0,
#   '3NTD4pp': 0.0,
#   'EX_feoxam_un_e': 0.0,
#   'ACACT5r': 0.34960648071330525,
#   'EX_for_e': 0.0,
#   'ACACT6r': 0.27315437675963494,
#   '3NTD7pp': 0.0,
#   '3NTD9pp': 0.0,
#   'EX_fru_e': 0.0,
#   '3OAR100': 0.0,
#   'ACACT7r': 0.27315437675963494,
#   'EX_frulys_e': 0.0,
#   'ACACT8r': 0.0,
#   'ACACt2pp': 0.0,
#   'ACACtex': 0.0,
#   '3OAR120': 0.0,
#   '3OAR121': 0.0,
#   '3OAR140': 0.0764521039536703,
#   'ACALD': 0.0,
#   '3OAR141': 0.0,
#   'EX_fruur_e': 0.0,
#   '3OAR160': 0.0,
#   'ACALDtex': 0.0,
#   'EX_fuc__L_e': 0.0,
#   '3OAR161': 0.0,
#   'EX_fum_e': 0.0,
#   'ACALDtpp': 0.0,
#   '3OAR180': 0.0,
#   'EX_fusa_e': 0.0,
#   'ACANTHAT': 0.0,
#   '3OAR181': 0.0,
#   'ACBIPGT': 0.0,
#   'EX_g1p_e': 0.0,
#   'ACCOAC': 0.07645799818454063,
#   '3OAR40': 0.0,
#   'EX_g3pc_e': 0.0,
#   '3OAR60': 0.0,
#   'ACCOAL': 996.7140693394712,
#   'ACGAL1PPpp': 0.0,
#   '3OAR80': 0.0,
#   'EX_g3pe_e': 0.0,
#   'ACGAL1Ptex': 0.0,
#   'ACGALtex': 0.0,
#   'ACGAM1PPpp': 0.0,
#   '3OAS100': 0.0,
#   'ACGAM1Ptex': 0.0,
#   'ACGAMK': 0.0,
#   'ACGAMT': 0.0,
#   '3OAS120': 0.0,
#   '3OAS121': 0.0,
#   '3OAS140': 0.07645210395366427,
#   'ACGAptspp': 0.0,
#   'EX_g3pg_e': 0.0,
#   'ACGAtex': 0.0,
#   'ACGK': 0.290577723230138,
#   'ACGS': 0.290577723230138,
#   '3OAS141': 0.0,
#   '3OAS160': 0.0,
#   '3OAS161': 0.0,
#   'ACHBS': 0.2854075003797559,
#   'EX_g3pi_e': 0.0,
#   '3OAS180': 0.0,
#   'ACKr': -995.9852065279903,
#   'EX_g3ps_e': 0.0,
#   'ACLS': 0.8588572223410017,
#   'ACM6PH': 0.0,
#   'ACMAMUT': 0.0,
#   '3OAS181': 0.0,
#   'EX_g6p_e': 0.0,
#   '3OAS60': 0.0,
#   'ACMANAptspp': 0.0,
#   'EX_gal_e': 0.0,
#   'ACMANAtex': 0.0,
#   'ACMUMptspp': 0.0,
#   '3OAS80': 0.0,
#   '3OXCOAT': 0.0,
#   'ACMUMtex': 0.0,
#   'EX_gal_bD_e': 0.0,
#   'ACNAMt2pp': 0.0,
#   '3PEPTabcpp': 0.0,
#   '3PEPTtex': 0.0,
#   '3UMPtex': 0.0,
#   'EX_gal1p_e': 0.0,
#   '42A12BOOXpp': 0.0,
#   'ACNAMtex': 0.0,
#   'ACNML': 0.0,
#   'ACOAD1f': -0.34960648071330525,
#   '4HOXPACDtex': 0.0,
#   '4HTHRS': 0.0,
#   'ACOAD2f': -0.34960648071330525,
#   'EX_galct__D_e': 0.0,
#   'ACOAD3f': -0.34960648071330525,
#   'ACOAD4f': -0.34960648071330525,
#   '4PCP': 0.0,
#   '4PCPpp': 0.0,
#   'ACOAD5f': -0.34960648071330525,
#   '4PEPTabcpp': 0.0,
#   'EX_galctn__D_e': 0.0,
#   '4PEPTtex': 0.0,
#   '5DGLCNR': 0.0,
#   'ACOAD6f': -0.27315437675963494,
#   'ACOAD7f': -0.12537814971472017,
#   'ACOAD8f': 0.0,
#   'ACOATA': 0.0,
#   '5DGLCNt2rpp': 0.0,
#   '5DGLCNtex': 0.0,
#   'ACODA': 0.290577723230138,
#   'EX_galctn__L_e': 0.0,
#   'ACOLIPAabctex': 0.0,
#   'ACONIs': 0.0,
#   'EX_galt_e': 0.0,
#   'ACONMT': 0.0,
#   'ACONTa': 4.8577766442263055,
#   'ACONTb': 4.8577766442263055,
#   'ACOTA': -0.2905777232301716,
#   'ACPPAT120': 0.0,
#   'AGM4PCPpp': 0.0,
#   'AGM4PH': 0.0,
#   'AGM4Pt2pp': 0.0,
#   'AGMH': 0.0,
#   'ACPPAT140': 0.0,
#   'EX_galur_e': 0.0,
#   'ACPPAT141': 0.0,
#   'ACPPAT160': 0.0,
#   'AGMHE': 0.0,
#   'AGMT': 0.0,
#   'ACPPAT161': 0.0,
#   'AGMt2pp': 0.0,
#   'EX_gam_e': 0.0,
#   'AGMtex': 0.0,
#   'ACPPAT180': 0.0,
#   'ACPPAT181': 0.0,
#   'ACPS1': 0.0,
#   'AGPAT120': 0.0,
#   'AGPAT140': 0.0,
#   'EX_gam6p_e': 0.0,
#   'ACS': 996.5575127691616,
#   'ACSERtex': 0.0,
#   'AGPAT141': 0.0,
#   'EX_gbbtn_e': 0.0,
#   'ACSERtpp': 0.0,
#   'AGPAT160': 0.0626890748573593,
#   'EX_gdp_e': 0.0,
#   'AGPAT161': 0.07388811352244685,
#   'AGPAT180': 0.0,
#   'AGPAT181': 0.0,
#   'AGPR': -0.2905777232301716,
#   'ACt2rpp': 0.0,
#   'ACt4pp': 0.0,
#   'ACtex': 0.0,
#   'ADA': 0.0,
#   'ADCL': 0.0006572067427141596,
#   'AGt3': 0.0,
#   'AHCYSNS': 0.00044010257210168574,
#   'ADCS': 0.0006572067427141596,
#   'AICART': 0.5331852484730462,
#   'AMALT3': 0.0,
#   'AIRC2': 0.4401173076788852,
#   'AIRC3': -0.4401173076788609,
#   'AKGDH': 3.8015383301567454,
#   'AKGt2rpp': 0.0,
#   'AKGtex': 0.0,
#   'ALAALAD': 0.0,
#   'ALAALAabcpp': 0.0,
#   'ADD': 0.0,
#   'ADEt2rpp': 0.0,
#   'ADEtex': 0.0,
#   'ADK1': 999.1368635660428,
#   'ADK3': -1000.0,
#   'ADK4': 0.0,
#   'ADMDC': 0.0,
#   'ADNCYC': 0.0,
#   'ADNK1': 0.0,
#   'ALAALAr': 0.027298147932015127,
#   'ALAALAtex': 0.0,
#   'ALAGLUE': 0.0,
#   'ALAR': 0.04094722189813638,
#   'ADNUC': 0.0,
#   'ADNt2pp_copy1': 1000.0,
#   'ADNt2pp_copy2': -1000.0,
#   'ADNtex': 0.0,
#   'ADOCBIK': 0.0,
#   'ADOCBLS': 0.0,
#   'ALATA_D2': 0.0,
#   'ALATA_L': 999.013189831423,
#   'ALATA_L2': 0.0,
#   'ALATRS': 0.0,
#   'ALAabcpp': 0.0,
#   'ALAt2pp_copy1': 0.0,
#   'ADOCBLabcpp': 0.0,
#   'ADOCBLtonex': 0.0,
#   'ALAt2pp_copy2': -1000.0,
#   'AMALT4': 0.0,
#   'ALAt4pp': 1000.0,
#   'ALAtex': 0.0,
#   'ALCD19': 0.0,
#   'ALCD2x': 0.0,
#   'ADPRDP': 0.0,
#   'ADPT': 0.0006611362299652555,
#   'ADSK': 0.24350246596426137,
#   'ADSL1r': 0.29376551976247356,
#   'ADSL2r': 0.4401173076788609,
#   'ADSS': 0.29376551976244575,
#   'AGDC': 0.0,
#   'ALDD19xr': 0.0,
#   'ALDD2x': 0.0,
#   'AMANAPEr': 0.0,
#   'ALDD2y': 0.0,
#   'ALDD3y': 0.0,
#   'ALDD4': 0.0,
#   'AGM3PA': 0.0,
#   'AGM3PApp': 0.0,
#   'AGM3PH': 0.0,
#   'AGM3Pt2pp': 0.0,
#   'AGM4PA': 0.0,
#   'ALLK': 0.0,
#   'ALLPI': 0.0,
#   'ALLTAMH': 0.0,
#   'ALLTN': 0.0,
#   'ALLTNt2rpp': 0.0,
#   'AGM4PApp': 0.0,
#   'AGM4PCP': 0.0,
#   'ALLTNtex': 0.0,
#   'AMANK': 0.0,
#   'ALLULPE': 0.0,
#   'AMAOTr': 1.9647436602099333e-06,
#   'ALLabcpp': 0.0,
#   'ALLtex': 0.0,
#   'AMMQLT8': 0.0,
#   'ALPATE160pp': 0.0,
#   'ASCBptspp': 0.0,
#   'ASCBtex': 0.0,
#   'ALPATG160pp': 0.0,
#   'AMPMS2': 0.00021906891423811587,
#   'ALR2': 0.0,
#   'ALR4x': 0.0,
#   'ASNN': 0.0,
#   'ASNNpp': 0.0,
#   'AMPN': 0.0,
#   'ASNS1': 0.0,
#   'ALTRH': 0.0,
#   'AM3PA': 0.0,
#   'ASNS2': 0.23680563731690144,
#   'AMPTASECG': 0.0,
#   'AM4PA': 0.0,
#   'ASNTRS': 0.0,
#   'AM4PCP': 0.0,
#   'AMALT1': 0.0,
#   'ASNabcpp': 0.0,
#   'ASNt2rpp': 0.0,
#   'ASNtex': 0.0,
#   'AMALT2': 0.0,
#   'ASO3t8pp': 0.0,
#   'AMPTASEPG': 0.0,
#   'ASO3tex': 0.0,
#   'ASP1DC': 0.0005658461641308685,
#   'AMPtex': 0.0,
#   'ASPCT': 0.3249636837910203,
#   'ANHGMtex': 0.0,
#   'ASPK': 1.0502301280629354,
#   'ASPO3': 0.0,
#   'ANHMK': 0.0,
#   'ASPO4': 0.0,
#   'ASPO5': 0.0,
#   'ANPRT': 0.055840960950839555,
#   'ASPO6': 0.0022378429893924923,
#   'ANS': 0.055840960950839555,
#   'AOBUTDs': 0.0,
#   'AOXSr2': 1.964743625453954e-06,
#   'ASPT': 0.0,
#   'CAT': 0.0,
#   'ASPTA': -2.876069326312745,
#   'AP4AH': 0.0,
#   'ASPTRS': 0.0,
#   'CAt6pp': -1000.0,
#   'CBIAT': 0.0,
#   'AP4AS': 0.0,
#   'CBItonex': 0.0,
#   'AP5AH': 0.0,
#   'CBIuabcpp': 0.0,
#   'ASPabcpp': 0.0,
#   'ASPt2_2pp': 0.0,
#   'ASPt2_3pp': 0.0,
#   'ASPt2pp_copy1': 0.0,
#   'CBL1abcpp': 0.0,
#   'CBL1tonex': 0.0,
#   'APCS': 0.0,
#   'CBLAT': 0.0,
#   'CBMD': 0.0,
#   'CBMKr': 0.6155414070211691,
#   'CBPS': 0.0,
#   'ASPt2pp_copy2': 0.0,
#   'ASPtex': 0.0,
#   'ASR': 0.0,
#   'AST': 0.0,
#   'ATHRDHr': 0.0,
#   'ATPHs': 0.0,
#   'ATPM': 3.15,
#   'CCGS': 0.0,
#   'CD2abcpp': 0.0,
#   'CD2t3pp': 0.0,
#   'CD2tex': 0.0,
#   'ATPPRT': 0.09306794079412835,
#   'APG3PAT120': 0.0,
#   'ATPS4rpp': 55.81524739984229,
#   'BALAt2pp': 0.0,
#   'BALAtex': 0.0,
#   'BETALDHx': 0.0,
#   'CD2tpp': 0.0,
#   'CDAPPA120': 0.0,
#   'CDAPPA140': 0.0,
#   'CDAPPA141': 0.0,
#   'CDAPPA160': 0.0,
#   'CDAPPA161': 0.0,
#   'CDAPPA180': 0.0,
#   'CDAPPA181': 0.0,
#   'CDGR': 0.0,
#   'BETALDHy': 0.0,
#   'BMOCOS': 0.00011984936115269119,
#   'BMOGDS1': 0.00011984936115269119,
#   'BMOGDS2': 0.00011984936115269119,
#   'BPNT': 0.24350246596426137,
#   'BSORx': 0.0,
#   'BSORy': 0.0,
#   'CDGS': 0.0,
#   'CDPMEK': 0.0023468862606047425,
#   'BTNt2ipp': 0.0,
#   'APG3PAT140': 0.0,
#   'BTNtex': 0.0,
#   'BTS5': 1.964743625453954e-06,
#   'BUTCT': 0.0,
#   'CFAS160E': 0.0,
#   'CFAS160G': 0.0,
#   'CFAS180E': 0.0,
#   'BUTSO3abcpp': 0.0,
#   'BUTSO3tex': 0.0,
#   'CFAS180G': 0.0,
#   'APG3PAT141': 0.0,
#   'CGLYabcpp': 0.0,
#   'CGLYtex': 0.0,
#   'CHLabcpp': 0.0,
#   'CHLt2pp': 0.0,
#   'CHLtex': 0.0,
#   'BUTt2rpp': 0.0,
#   'BUTtex': 0.0,
#   'BWCOGDS1': 0.0,
#   'BWCOGDS2': 0.0,
#   'BWCOS': 0.0,
#   'CA2t3pp': 999.9948867547148,
#   'CA2tex': 0.005113245285201629,
#   'CADVtpp': 0.0,
#   'CHOLD': 0.0,
#   'CHORM': 0.31768332628690077,
#   'CHORS': 0.37440056289469253,
#   'CHRPL': 0.00021906891423811587,
#   'CHTBSptspp': 0.0,
#   'CHTBStex': 0.0,
#   'CINNDO': 0.0,
#   'CITL': 0.0,
#   'CLt3_2pp': 0.002556622642621958,
#   'CITt3pp': 0.0,
#   'APG3PAT160': 0.0,
#   'CITt7pp': 0.0,
#   'CITtex': 0.0,
#   'CLtex': 0.005113245285201629,
#   'CMPN': 0.0,
#   'CMPtex': 0.0,
#   'CLIPAabctex': 0.0,
#   'APG3PAT161': 0.0,
#   'CLPNH120pp': 0.0,
#   'CLPNH140pp': 0.0,
#   'CLPNH141pp': 0.0,
#   'CMtex': 0.0,
#   'CMtpp': 0.0,
#   'CO2tex': -19.675222635663204,
#   'CLPNH160pp': 0.0,
#   'CO2tpp': -19.675222635663204,
#   'COBALT2abcpp': 0.0,
#   'COBALT2t3pp': 0.0,
#   'COBALT2tex': 2.4559295297876815e-05,
#   'CLPNH161pp': 0.0,
#   'CLPNH180pp': 0.0,
#   'CLPNH181pp': 0.0,
#   'CLPNS120pp': 0.0,
#   'CLPNS140pp': 0.0,
#   'COBALT2tpp': 2.455929531817443e-05,
#   'APG3PAT180': 0.0,
#   'COLIPAKpp': 0.0,
#   'CLPNS141pp': 0.0,
#   'CLPNS160pp': 0.0,
#   'APG3PAT181': 0.0,
#   'CLPNS161pp': 0.0,
#   'COLIPAPabctex': 0.0,
#   'COLIPAabcpp': 0.0,
#   'APH120': 0.0,
#   'COLIPAabctex': 0.0,
#   'CLPNS180pp': 0.0,
#   'APH140': 0.0,
#   'CLPNS181pp': 0.0,
#   'CPGNR1': 0.0,
#   'APH141': 0.0,
#   'APH160': 0.0,
#   'CPGNR2': 0.0,
#   'CPGNR3': 0.0,
#   'APH161': 0.0,
#   'CYANSTpp': 0.0,
#   'CPGNUtex': 0.0,
#   'APH180': 0.0,
#   'APH181': 0.0,
#   'CPGNUtpp': 0.0,
#   'APPLDHr': 0.0,
#   'CPGNabcpp': 0.0,
#   'CPGNexs': 0.0,
#   'CPGNtonex': 0.0,
#   'CPH4S': 0.0,
#   'CPMPS': 0.00023969872230538238,
#   'CYANtex': 0.0,
#   'CYNTAH': 0.0,
#   'CYNTt2pp': 0.0,
#   'CYNTtex': 0.0,
#   'CYSDDS': 0.0,
#   'CYSDS': 0.0,
#   'CYSDabcpp': 0.0,
#   'CYSDtex': 0.0,
#   'CYSS': 0.24350246596426137,
#   'CYSSADS': 0.0,
#   'CPPPGO': 0.00021906891423811587,
#   'CPPPGO2': 0.0,
#   'CRNBTCT': 0.0,
#   'CRNCAL2': 0.0,
#   'CRNCAR': 0.0,
#   'CRNCBCT': 0.0,
#   'CYSTL': 0.15119782806862175,
#   'APRAUR': 0.0004381378284763145,
#   'CYSTRS': 0.0,
#   'CYSabc2pp': 0.0,
#   'CRNCDH': 0.0,
#   'CRNDCAL2': 0.0,
#   'ARAI': 0.0,
#   'CRNDabcpp': 0.0,
#   'CYSabcpp': 0.0,
#   'CYStex': 0.0,
#   'ARBTNR1': 0.0,
#   'CYStpp': 0.0,
#   'CYTBD2pp': 0.0,
#   'CYTBDpp': 0.0,
#   'CYTBO3_4pp': 35.149539494651926,
#   'CYTD': 0.0,
#   'CRNDt2rpp': 1000.0,
#   'CRNDtex': 0.0,
#   'CRNabcpp': 0.0,
#   'CRNt2rpp': -1000.0,
#   'CRNt7pp': 0.0,
#   'CYTDH': 0.0,
#   'CRNt8pp': 1000.0,
#   'CYTDK2': 0.0,
#   'ARBTNR2': 0.0,
#   'CYTDt2pp_copy1': 0.0,
#   'CRNtex': 0.0,
#   'CS': 4.857776644226289,
#   'CSND': 0.0,
#   'CYTDt2pp_copy2': 0.0,
#   'CYTDtex': 0.0,
#   'CSNt2pp': 0.0,
#   'ARBTNR3': 0.0,
#   'CSNtex': 0.0,
#   'CTBTCAL2': 0.0,
#   'CTBTabcpp': 0.0,
#   'CYTK1': 0.17771597278135687,
#   'CYTK2': 0.0,
#   'D_LACt2pp': 0.0,
#   'D_LACtex': 0.0,
#   'CTBTt2rpp': 0.0,
#   'CTECOAI6': 0.0,
#   'ARBTNabcpp': 0.0,
#   'CTECOAI7': -0.14777622704491478,
#   'CTECOAI8': 0.0,
#   'DAAD': 0.0,
#   'DADA': 0.0,
#   'DADK': 0.0,
#   'DADNt2pp': 0.0,
#   'DADNtex': 0.0,
#   'DAGK120': 0.0,
#   'CTPS2': 0.15769523523799794,
#   'CU1Opp': 0.0,
#   'CU1abcpp': 0.0,
#   'CU2abcpp': 0.0,
#   'CU2tex': 0.0006965016152662429,
#   'DAGK140': 0.0,
#   'ARBTNexs': 0.0,
#   'DAGK141': 0.0,
#   'DAGK160': 0.0,
#   'CU2tpp': 0.0006965016152234268,
#   'CUt3': 0.0,
#   'CUtex': 0.0,
#   'DAGK161': 0.0,
#   'ARBTNtex': 0.0,
#   'DAGK180': 0.0,
#   'DAGK181': 0.0,
#   'CYANST': 0.0,
#   'DALAt2pp': 0.01364907396602862,
#   'ARBTNtonex': 0.0,
#   'DALAtex': 0.0,
#   'DAMPtex': 0.0,
#   'DCYTt2pp': 0.0,
#   'ARBTNtpp': 0.0,
#   'DCYTtex': 0.0,
#   'DDCAtexi': 0.0,
#   'DAPAL': 0.0,
#   'DAPDC': 0.33711169362720217,
#   'DAPE': 0.3644098415592225,
#   'DAPabcpp': 0.0,
#   'DDGALK': 0.0,
#   'DDGLCNt2rpp': 0.0,
#   'DDGLCNtex': 0.0,
#   'DDGLK': 0.0,
#   'DDPA': 0.37440056289469253,
#   'DAPtex': 0.0,
#   'DASYN120': 0.0,
#   'DASYN140': 0.0,
#   'DASYN141': 0.0,
#   'DASYN160': 0.0626890748573593,
#   'DDPGALA': 0.0,
#   'DGK1': 0.0,
#   'DGMPtex': 0.0,
#   'DASYN161': 0.07388811352244685,
#   'ARBTptspp': 0.0,
#   'DASYN180': 0.0,
#   'DASYN181': 0.0,
#   'DGSNt2pp': 0.0,
#   'DGSNtex': 0.0,
#   'DHACOAH': 0.0,
#   'DATPHs': 0.0,
#   'DB4PS': 0.000876275656952629,
#   'DHAD1': 0.8588572223410017,
#   'ARBTtex': 0.0,
#   'DHAD2': 0.2854075003797559,
#   'DHAPT': 0.8653751925204691,
#   'DBTS': 1.964743625453954e-06,
#   'DC6PH': 0.0,
#   'DCAtex': 0.0,
#   'DHAtex': 0.0,
#   'ARBabcpp': 0.0,
#   'DHAtpp': 0.0,
#   'DHBD': 0.0,
#   'DHBS': 0.0,
#   'DHBSH': 0.0,
#   'DHCIND': 0.0,
#   'DCMPtex': 0.0,
#   'DCTPD': 0.0,
#   'DCYTD': 0.0,
#   'DHCINDO': 0.0,
#   'ARBt2rpp': 0.0,
#   'DHDPRy': 0.3644098415592594,
#   'DHDPS': 0.3644098415592594,
#   'ARBt3ipp': 0.0,
#   'DHFR': 0.02636194759452337,
#   'DHFS': 0.0006572067427141596,
#   'FFSD': 0.0,
#   'ARBtex': 0.0,
#   'DNMPPA': 0.0006572067427141596,
#   'DHMPTR': 0.0,
#   'DHNAOT4': 0.0,
#   'DHNCOAS': 0.0,
#   'DNTPPA': 0.0006572067427141596,
#   'ARGAGMt7pp': 0.0,
#   'DOGULNR': 0.0,
#   'DHNCOAT': 0.0,
#   'DHNPA2r': 0.0006572067427441652,
#   'DOPAtex': 0.0,
#   'ARGDC': 0.0,
#   'DHNPTE': 0.0,
#   'DOXRBCNtex': 0.0,
#   'ARGDCpp': 0.0,
#   'DOXRBCNtpp': 0.0,
#   'DHORD2': 0.3249636837910203,
#   'ARGORNt7pp': 0.0,
#   'DHORD5': 0.0,
#   'DHORDfum': 0.0,
#   'DHORTS': -0.3249636837909975,
#   'DHPPD': 0.0,
#   'DPCOAK': 0.0005658461641308685,
#   ...})
